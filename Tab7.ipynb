# %% [markdown]
# Table 7: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in Wales, 2001 to 2016

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/healthandsocialcare/causesofdeath/datasets/alcoholspecificdeathsintheukmaindataset')
    sheet = scraper.distribution().as_databaker()
# Out:
# WARNING:Unexpected "next release" field: ('Unknown string format:', 'To be announced')

# %%
tab = next(tab for tab in sheet if tab.name=='Table 7')

# %%
observations = tab.excel_ref('C7').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<I15 18.2>, <E12 6.8>, <K11 17.0>, <D18 9.6>, <H7 181.0>, <F8 7.6>, <I14 19.6>, <J8 11.1>, <J16 15.4>, <C21 132.0>, <E20 6.3>, <I12 15.5>, <F17 9.7>, <I22 17.4>, <J15 16.0>, <C8 89.0>, <J20 13.5>, <D12 8.3>, <E22 6.9>, <I18 17.6>, <F21 9.9>, <J17 14.6>, <E21 7.0>, <F7 8.3>, <E14 8.3>, <J19 14.9>, <E19 7.1>, <H12 218.0>, <E16 7.5>, <E7 5.5>, <H20 230.0>, <C22 130.0>, <K19 19.1>, <D7 6.8>, <K21 17.4>, <D9 6.4>, <H21 229.0>, <K13 20.2>, <E9 5.2>, <C18 149.0>, <D21 8.5>, <J14 17.3>, <H8 173.0>, <C16 137.0>, <K17 18.8>, <J18 15.4>, <D17 8.3>, <I10 14.9>, <F16 10.5>, <D19 8.6>, <J22 15.2>, <I20 15.5>, <J12 13.5>, <I16 17.5>, <F11 9.2>, <D11 7.7>, <I11 14.9>, <F13 9.4>, <J11 12.9>, <H10 204.0>, <D13 7.9>, <F15 9.4>, <I7 13.6>, <H9 193.0>, <J9 12.5>, <D15 7.9>, <K7 15.5>, <C15 121.0>, <K9 16.6>, <H18 255.0>, <C12 122.0>, <E11 6.3>, <K12 17.6>, <E13 6.5>, <K10 17.0>, <C13 118.0>, <E15 6.5>, <J7 11.6>, <C11 114.0>, <E17 6.9>, <F19 10.1>, <C19 133.0>, <H16 254.0>, <H14 278.0>, <F20 9.1>, <F22 9.8>, <H17 243.0>, <J21 13.4>, <I19 17.0>, <H19 253.0>, <K15 20.5>, <C17 129.0>, <K22 19.5>, <E8 5.0>, <K18 19.7>, <K14 21.9>, <J13 15.8>, <D16 9.0>, <H13 255.0>, <F14 11.5>, <D8 6.2>, <D10 7.8>, <D14 9.9>, <H22 258.0>, <K20 17.5>, <H11 207.0>, <F18 11.2>, <D22 8.3>, <C7 96.0>, <C14 148.0>, <C10 115.0>, <F9 7.9>, <I9 14.6>, <F10 9.3>, <E18 8.1>, <C9 93.0>, <E10 6.4>, <F12 9.7>, <I21 15.4>, <C20 121.0>, <K16 19.7>, <I8 13.0>, <J10 12.9>, <K8 15.0>, <I13 18.0>, <D20 7.7>, <I17 16.7>, <H15 262.0>}

# %%
Sex = tab.excel_ref('C5').expand(RIGHT).is_not_whitespace()
Sex
# Out:
# {<C5 'Females'>, <H5 'Males'>}

# %%
deaths = tab.excel_ref('C6').expand(RIGHT).is_not_blank()
deaths
# Out:
# {<E6 'Lower 95% confidence limit'>, <H6 'Deaths'>, <I6 'Rate per 100,000 persons1'>, <D6 'Rate per 100,000 persons1'>, <K6 'Upper 95% confidence limit'>, <C6 'Deaths'>, <F6 'Upper 95% confidence limit'>, <J6 'Lower 95% confidence limit'>}

# %%
# lc = tab.excel_ref('D6').expand(RIGHT).filter(contains_string('Lower 95% confidence limit'))
# lc

# %%
# uc = tab.excel_ref('F6').expand(RIGHT).filter(contains_string('Upper 95% confidence limit'))
# uc

# %%
Year = tab.excel_ref('A7').expand(DOWN) - tab.excel_ref('A23').expand(DOWN)  
Year
# Out:
# {<A10 2004.0>, <A19 2013.0>, <A22 2016.0>, <A7 2001.0>, <A15 2009.0>, <A9 2003.0>, <A16 2010.0>, <A18 2012.0>, <A11 2005.0>, <A12 2006.0>, <A21 2015.0>, <A20 2014.0>, <A13 2007.0>, <A14 2008.0>, <A8 2002.0>, <A17 2011.0>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(Sex,'Sex',CLOSEST,LEFT),
            HDim(deaths, 'Alcohol Specific Deaths',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Sex</td><td class="xc3" style="background-color:LightGray">Alcohol Specific Deaths</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 7</caption>
# <tr><td title="0 0">Back to contents</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td><td title="11 0"></td></tr>
# <tr><td style="font-weight:bold" title="0 1">Table 7: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in Wales, 2001 to 20161,2,3,4</td><td style="font-weight:bold" title="1 1"></td><td style="font-weight:bold" title="2 1"></td><td style="font-weight:bold" title="3 1"></td><td style="font-weight:bold" title="4 1"></td><td style="font-weight:bold" title="5 1"></td><td style="font-weight:bold" title="6 1"></td><td style="font-weight:bold" title="7 1"></td><td style="font-weight:bold" title="8 1"></td><td style="font-weight:bold" title="9 1"></td><td style="font-weight:bold" title="10 1"></td><td title="11 1"></td></tr>
# <tr><td style="font-weight:bold" title="0 2"></td><td style="font-weight:bold" title="1 2"></td><td style="font-weight:bold" title="2 2"></td><td style="font-weight:bold" title="3 2"></td><td style="font-weight:bold" title="4 2"></td><td style="font-weight:bold" title="5 2"></td><td style="font-weight:bold" title="6 2"></td><td style="font-weight:bold" title="7 2"></td><td style="font-weight:bold" title="8 2"></td><td style="font-weight:bold" title="9 2"></td><td style="font-weight:bold" title="10 2"></td><td title="11 2"></td></tr>
# <tr><td style="font-weight:bold" title="0 3"></td><td style="font-weight:bold" title="1 3"></td><td style="font-weight:bold" title="2 3"></td><td style="font-weight:bold" title="3 3"></td><td style="font-weight:bold" title="4 3"></td><td style="font-weight:bold" title="5 3"></td><td style="font-weight:bold" title="6 3"></td><td title="7 3"></td><td title="8 3"></td><td title="9 3"></td><td title="10 3"></td><td title="11 3"></td></tr>
# <tr><td style="font-weight:bold" title="0 4"></td><td style="font-weight:bold" title="1 4"></td><td style="background-color:MistyRose;font-weight:bold" title="2 4">Females</td><td style="font-weight:bold" title="3 4"></td><td style="font-weight:bold" title="4 4"></td><td style="font-weight:bold" title="5 4"></td><td style="font-weight:bold" title="6 4"></td><td style="background-color:MistyRose;font-weight:bold" title="7 4">Males</td><td style="font-weight:bold" title="8 4"></td><td style="font-weight:bold" title="9 4"></td><td style="font-weight:bold" title="10 4"></td><td title="11 4"></td></tr>
# <tr><td style="font-weight:bold" title="0 5">Year</td><td style="font-weight:bold" title="1 5"></td><td style="background-color:LightGray;font-weight:bold" title="2 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="3 5">Rate per 100,000 persons1</td><td style="background-color:LightGray;font-weight:bold" title="4 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="5 5">Upper 95% confidence limit</td><td title="6 5"></td><td style="background-color:LightGray;font-weight:bold" title="7 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="8 5">Rate per 100,000 persons1</td><td style="background-color:LightGray;font-weight:bold" title="9 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="10 5">Upper 95% confidence limit</td><td title="11 5"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">2001.0</td><td title="1 6"></td><td style="background-color:Aqua" title="2 6">96.0</td><td style="background-color:Aqua" title="3 6">6.8</td><td style="background-color:Aqua" title="4 6">5.5</td><td style="background-color:Aqua" title="5 6">8.3</td><td title="6 6"></td><td style="background-color:Aqua" title="7 6">181.0</td><td style="background-color:Aqua" title="8 6">13.6</td><td style="background-color:Aqua" title="9 6">11.6</td><td style="background-color:Aqua" title="10 6">15.5</td><td title="11 6"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 7">2002.0</td><td title="1 7"></td><td style="background-color:Aqua" title="2 7">89.0</td><td style="background-color:Aqua" title="3 7">6.2</td><td style="background-color:Aqua" title="4 7">5.0</td><td style="background-color:Aqua" title="5 7">7.6</td><td title="6 7"></td><td style="background-color:Aqua" title="7 7">173.0</td><td style="background-color:Aqua" title="8 7">13.0</td><td style="background-color:Aqua" title="9 7">11.1</td><td style="background-color:Aqua" title="10 7">15.0</td><td title="11 7"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 8">2003.0</td><td title="1 8"></td><td style="background-color:Aqua" title="2 8">93.0</td><td style="background-color:Aqua" title="3 8">6.4</td><td style="background-color:Aqua" title="4 8">5.2</td><td style="background-color:Aqua" title="5 8">7.9</td><td title="6 8"></td><td style="background-color:Aqua" title="7 8">193.0</td><td style="background-color:Aqua" title="8 8">14.6</td><td style="background-color:Aqua" title="9 8">12.5</td><td style="background-color:Aqua" title="10 8">16.6</td><td title="11 8"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 9">2004.0</td><td title="1 9"></td><td style="background-color:Aqua" title="2 9">115.0</td><td style="background-color:Aqua" title="3 9">7.8</td><td style="background-color:Aqua" title="4 9">6.4</td><td style="background-color:Aqua" title="5 9">9.3</td><td title="6 9"></td><td style="background-color:Aqua" title="7 9">204.0</td><td style="background-color:Aqua" title="8 9">14.9</td><td style="background-color:Aqua" title="9 9">12.9</td><td style="background-color:Aqua" title="10 9">17.0</td><td title="11 9"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 10">2005.0</td><td title="1 10"></td><td style="background-color:Aqua" title="2 10">114.0</td><td style="background-color:Aqua" title="3 10">7.7</td><td style="background-color:Aqua" title="4 10">6.3</td><td style="background-color:Aqua" title="5 10">9.2</td><td title="6 10"></td><td style="background-color:Aqua" title="7 10">207.0</td><td style="background-color:Aqua" title="8 10">14.9</td><td style="background-color:Aqua" title="9 10">12.9</td><td style="background-color:Aqua" title="10 10">17.0</td><td title="11 10"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 11">2006.0</td><td title="1 11"></td><td style="background-color:Aqua" title="2 11">122.0</td><td style="background-color:Aqua" title="3 11">8.3</td><td style="background-color:Aqua" title="4 11">6.8</td><td style="background-color:Aqua" title="5 11">9.7</td><td title="6 11"></td><td style="background-color:Aqua" title="7 11">218.0</td><td style="background-color:Aqua" title="8 11">15.5</td><td style="background-color:Aqua" title="9 11">13.5</td><td style="background-color:Aqua" title="10 11">17.6</td><td title="11 11"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 12">2007.0</td><td title="1 12"></td><td style="background-color:Aqua" title="2 12">118.0</td><td style="background-color:Aqua" title="3 12">7.9</td><td style="background-color:Aqua" title="4 12">6.5</td><td style="background-color:Aqua" title="5 12">9.4</td><td title="6 12"></td><td style="background-color:Aqua" title="7 12">255.0</td><td style="back

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS    Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 0     96.0  2001.0  Females                      Deaths        Count  People
# 1      6.8  2001.0  Females   Rate per 100,000 persons1        Count  People
# 2      5.5  2001.0  Females  Lower 95% confidence limit        Count  People
# 3      8.3  2001.0  Females  Upper 95% confidence limit        Count  People
# 4    181.0  2001.0    Males                      Deaths        Count  People
# 5     13.6  2001.0    Males   Rate per 100,000 persons1        Count  People
# 6     11.6  2001.0    Males  Lower 95% confidence limit        Count  People
# 7     15.5  2001.0    Males  Upper 95% confidence limit        Count  People
# 8     89.0  2002.0  Females                      Deaths        Count  People
# 9      6.2  2002.0  Females   Rate per 100,000 persons1        Count  People
# 10     5.0  2002.0  Females  Lower 95% confidence limit        Count  People
# 11     7.6  2002.0  Females  Upper 95% confidence limit        Count  People
# 12   173.0  2002.0    Males                      Deaths        Count  People
# 13    13.0  2002.0    Males   Rate per 100,000 persons1        Count  People
# 14    11.1  2002.0    Males  Lower 95% confidence limit        Count  People
# 15    15.0  2002.0    Males  Upper 95% confidence limit        Count  People
# 16    93.0  2003.0  Females                      Deaths        Count  People
# 17     6.4  2003.0  Females   Rate per 100,000 persons1        Count  People
# 18     5.2  2003.0  Females  Lower 95% confidence limit        Count  People
# 19     7.9  2003.0  Females  Upper 95% confidence limit        Count  People
# 20   193.0  2003.0    Males                      Deaths        Count  People
# 21    14.6  2003.0    Males   Rate per 100,000 persons1        Count  People
# 22    12.5  2003.0    Males  Lower 95% confidence limit        Count  People
# 23    16.6  2003.0    Males  Upper 95% confidence limit        Count  People
# 24   115.0  2004.0  Females                      Deaths        Count  People
# 25     7.8  2004.0  Females   Rate per 100,000 persons1        Count  People
# 26     6.4  2004.0  Females  Lower 95% confidence limit        Count  People
# 27     9.3  2004.0  Females  Upper 95% confidence limit        Count  People
# 28   204.0  2004.0    Males                      Deaths        Count  People
# 29    14.9  2004.0    Males   Rate per 100,000 persons1        Count  People
# ..     ...     ...      ...                         ...          ...     ...
# 98     7.1  2013.0  Females  Lower 95% confidence limit        Count  People
# 99    10.1  2013.0  Females  Upper 95% confidence limit        Count  People
# 100  253.0  2013.0    Males                      Deaths        Count  People
# 101   17.0  2013.0    Males   Rate per 100,000 persons1        Count  People
# 102   14.9  2013.0    Males  Lower 95% confidence limit        Count  People
# 103   19.1  2013.0    Males  Upper 95% confidence limit        Count  People
# 104  121.0  2014.0  Females                      Deaths        Count  People
# 105    7.7  2014.0  Females   Rate per 100,000 persons1        Count  People
# 106    6.3  2014.0  Females  Lower 95% confidence limit        Count  People
# 107    9.1  2014.0  Females  Upper 95% confidence limit        Count  People
# 108  230.0  2014.0    Males                      Deaths        Count  People
# 109   15.5  2014.0    Males   Rate per 100,000 persons1        Count  People
# 110   13.5  2014.0    Males  Lower 95% confidence limit        Count  People
# 111   17.5  2014.0    Males  Upper 95% confidence limit        Count  People
# 112  132.0  2015.0  Females                      Deaths        Count  People
# 113    8.5  2015.0  Females   Rate per 100,000 persons1        Count  People
# 114    7.0  2015.0  Females  Lower 95% confidence limit        Count  People
# 115    9.9  2015.0  Females  Upper 95% confidence limit        Count  People
# 116  229.0  2015.0    Males                      Deaths        Count  People
# 117   15.4  2015.0    Males   Rate per 100,000 persons1        Count  People
# 118   13.4  2015.0    Males  Lower 95% confidence limit        Count  People
# 119   17.4  2015.0    Males  Upper 95% confidence limit        Count  People
# 120  130.0  2016.0  Females                      Deaths        Count  People
# 121    8.3  2016.0  Females   Rate per 100,000 persons1        Count  People
# 122    6.9  2016.0  Females  Lower 95% confidence limit        Count  People
# 123    9.8  2016.0  Females  Upper 95% confidence limit        Count  People
# 124  258.0  2016.0    Males                      Deaths        Count  People
# 125   17.4  2016.0    Males   Rate per 100,000 persons1        Count  People
# 126   15.2  2016.0    Males  Lower 95% confidence limit        Count  People
# 127   19.5  2016.0    Males  Upper 95% confidence limit        Count  People
#
# [128 rows x 6 columns]

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
# new_table['Year'] = new_table['Year'].astype(str)

# %%
# new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value                      float64
# Year                         int64
# Sex                         object
# Alcohol Specific Deaths     object
# Measure Type                object
# Unit                        object
# dtype: object

# %%
new_table
# Out:
#      Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 0     96.0  2001  Females                      Deaths        Count  People
# 1      6.8  2001  Females   Rate per 100,000 persons1        Count  People
# 2      5.5  2001  Females  Lower 95% confidence limit        Count  People
# 3      8.3  2001  Females  Upper 95% confidence limit        Count  People
# 4    181.0  2001    Males                      Deaths        Count  People
# 5     13.6  2001    Males   Rate per 100,000 persons1        Count  People
# 6     11.6  2001    Males  Lower 95% confidence limit        Count  People
# 7     15.5  2001    Males  Upper 95% confidence limit        Count  People
# 8     89.0  2002  Females                      Deaths        Count  People
# 9      6.2  2002  Females   Rate per 100,000 persons1        Count  People
# 10     5.0  2002  Females  Lower 95% confidence limit        Count  People
# 11     7.6  2002  Females  Upper 95% confidence limit        Count  People
# 12   173.0  2002    Males                      Deaths        Count  People
# 13    13.0  2002    Males   Rate per 100,000 persons1        Count  People
# 14    11.1  2002    Males  Lower 95% confidence limit        Count  People
# 15    15.0  2002    Males  Upper 95% confidence limit        Count  People
# 16    93.0  2003  Females                      Deaths        Count  People
# 17     6.4  2003  Females   Rate per 100,000 persons1        Count  People
# 18     5.2  2003  Females  Lower 95% confidence limit        Count  People
# 19     7.9  2003  Females  Upper 95% confidence limit        Count  People
# 20   193.0  2003    Males                      Deaths        Count  People
# 21    14.6  2003    Males   Rate per 100,000 persons1        Count  People
# 22    12.5  2003    Males  Lower 95% confidence limit        Count  People
# 23    16.6  2003    Males  Upper 95% confidence limit        Count  People
# 24   115.0  2004  Females                      Deaths        Count  People
# 25     7.8  2004  Females   Rate per 100,000 persons1        Count  People
# 26     6.4  2004  Females  Lower 95% confidence limit        Count  People
# 27     9.3  2004  Females  Upper 95% confidence limit        Count  People
# 28   204.0  2004    Males                      Deaths        Count  People
# 29    14.9  2004    Males   Rate per 100,000 persons1        Count  People
# ..     ...   ...      ...                         ...          ...     ...
# 98     7.1  2013  Females  Lower 95% confidence limit        Count  People
# 99    10.1  2013  Females  Upper 95% confidence limit        Count  People
# 100  253.0  2013    Males                      Deaths        Count  People
# 101   17.0  2013    Males   Rate per 100,000 persons1        Count  People
# 102   14.9  2013    Males  Lower 95% confidence limit        Count  People
# 103   19.1  2013    Males  Upper 95% confidence limit        Count  People
# 104  121.0  2014  Females                      Deaths        Count  People
# 105    7.7  2014  Females   Rate per 100,000 persons1        Count  People
# 106    6.3  2014  Females  Lower 95% confidence limit        Count  People
# 107    9.1  2014  Females  Upper 95% confidence limit        Count  People
# 108  230.0  2014    Males                      Deaths        Count  People
# 109   15.5  2014    Males   Rate per 100,000 persons1        Count  People
# 110   13.5  2014    Males  Lower 95% confidence limit        Count  People
# 111   17.5  2014    Males  Upper 95% confidence limit        Count  People
# 112  132.0  2015  Females                      Deaths        Count  People
# 113    8.5  2015  Females   Rate per 100,000 persons1        Count  People
# 114    7.0  2015  Females  Lower 95% confidence limit        Count  People
# 115    9.9  2015  Females  Upper 95% confidence limit        Count  People
# 116  229.0  2015    Males                      Deaths        Count  People
# 117   15.4  2015    Males   Rate per 100,000 persons1        Count  People
# 118   13.4  2015    Males  Lower 95% confidence limit        Count  People
# 119   17.4  2015    Males  Upper 95% confidence limit        Count  People
# 120  130.0  2016  Females                      Deaths        Count  People
# 121    8.3  2016  Females   Rate per 100,000 persons1        Count  People
# 122    6.9  2016  Females  Lower 95% confidence limit        Count  People
# 123    9.8  2016  Females  Upper 95% confidence limit        Count  People
# 124  258.0  2016    Males                      Deaths        Count  People
# 125   17.4  2016    Males   Rate per 100,000 persons1        Count  People
# 126   15.2  2016    Males  Lower 95% confidence limit        Count  People
# 127   19.5  2016    Males  Upper 95% confidence limit        Count  People
#
# [128 rows x 6 columns]

# %%
nt1 = new_table[new_table['Alcohol Specific Deaths'] == 'Lower 95% confidence limit']

# %%
nt1
# Out:
#      Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 2      5.5  2001  Females  Lower 95% confidence limit        Count  People
# 6     11.6  2001    Males  Lower 95% confidence limit        Count  People
# 10     5.0  2002  Females  Lower 95% confidence limit        Count  People
# 14    11.1  2002    Males  Lower 95% confidence limit        Count  People
# 18     5.2  2003  Females  Lower 95% confidence limit        Count  People
# 22    12.5  2003    Males  Lower 95% confidence limit        Count  People
# 26     6.4  2004  Females  Lower 95% confidence limit        Count  People
# 30    12.9  2004    Males  Lower 95% confidence limit        Count  People
# 34     6.3  2005  Females  Lower 95% confidence limit        Count  People
# 38    12.9  2005    Males  Lower 95% confidence limit        Count  People
# 42     6.8  2006  Females  Lower 95% confidence limit        Count  People
# 46    13.5  2006    Males  Lower 95% confidence limit        Count  People
# 50     6.5  2007  Females  Lower 95% confidence limit        Count  People
# 54    15.8  2007    Males  Lower 95% confidence limit        Count  People
# 58     8.3  2008  Females  Lower 95% confidence limit        Count  People
# 62    17.3  2008    Males  Lower 95% confidence limit        Count  People
# 66     6.5  2009  Females  Lower 95% confidence limit        Count  People
# 70    16.0  2009    Males  Lower 95% confidence limit        Count  People
# 74     7.5  2010  Females  Lower 95% confidence limit        Count  People
# 78    15.4  2010    Males  Lower 95% confidence limit        Count  People
# 82     6.9  2011  Females  Lower 95% confidence limit        Count  People
# 86    14.6  2011    Males  Lower 95% confidence limit        Count  People
# 90     8.1  2012  Females  Lower 95% confidence limit        Count  People
# 94    15.4  2012    Males  Lower 95% confidence limit        Count  People
# 98     7.1  2013  Females  Lower 95% confidence limit        Count  People
# 102   14.9  2013    Males  Lower 95% confidence limit        Count  People
# 106    6.3  2014  Females  Lower 95% confidence limit        Count  People
# 110   13.5  2014    Males  Lower 95% confidence limit        Count  People
# 114    7.0  2015  Females  Lower 95% confidence limit        Count  People
# 118   13.4  2015    Males  Lower 95% confidence limit        Count  People
# 122    6.9  2016  Females  Lower 95% confidence limit        Count  People
# 126   15.2  2016    Males  Lower 95% confidence limit        Count  People

# %%
nt1.columns = ['Lower 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
nt2 = new_table[new_table['Alcohol Specific Deaths'] == 'Upper 95% confidence limit']

# %%
nt2
# Out:
#      Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 3      8.3  2001  Females  Upper 95% confidence limit        Count  People
# 7     15.5  2001    Males  Upper 95% confidence limit        Count  People
# 11     7.6  2002  Females  Upper 95% confidence limit        Count  People
# 15    15.0  2002    Males  Upper 95% confidence limit        Count  People
# 19     7.9  2003  Females  Upper 95% confidence limit        Count  People
# 23    16.6  2003    Males  Upper 95% confidence limit        Count  People
# 27     9.3  2004  Females  Upper 95% confidence limit        Count  People
# 31    17.0  2004    Males  Upper 95% confidence limit        Count  People
# 35     9.2  2005  Females  Upper 95% confidence limit        Count  People
# 39    17.0  2005    Males  Upper 95% confidence limit        Count  People
# 43     9.7  2006  Females  Upper 95% confidence limit        Count  People
# 47    17.6  2006    Males  Upper 95% confidence limit        Count  People
# 51     9.4  2007  Females  Upper 95% confidence limit        Count  People
# 55    20.2  2007    Males  Upper 95% confidence limit        Count  People
# 59    11.5  2008  Females  Upper 95% confidence limit        Count  People
# 63    21.9  2008    Males  Upper 95% confidence limit        Count  People
# 67     9.4  2009  Females  Upper 95% confidence limit        Count  People
# 71    20.5  2009    Males  Upper 95% confidence limit        Count  People
# 75    10.5  2010  Females  Upper 95% confidence limit        Count  People
# 79    19.7  2010    Males  Upper 95% confidence limit        Count  People
# 83     9.7  2011  Females  Upper 95% confidence limit        Count  People
# 87    18.8  2011    Males  Upper 95% confidence limit        Count  People
# 91    11.2  2012  Females  Upper 95% confidence limit        Count  People
# 95    19.7  2012    Males  Upper 95% confidence limit        Count  People
# 99    10.1  2013  Females  Upper 95% confidence limit        Count  People
# 103   19.1  2013    Males  Upper 95% confidence limit        Count  People
# 107    9.1  2014  Females  Upper 95% confidence limit        Count  People
# 111   17.5  2014    Males  Upper 95% confidence limit        Count  People
# 115    9.9  2015  Females  Upper 95% confidence limit        Count  People
# 119   17.4  2015    Males  Upper 95% confidence limit        Count  People
# 123    9.8  2016  Females  Upper 95% confidence limit        Count  People
# 127   19.5  2016    Males  Upper 95% confidence limit        Count  People

# %%
nt2.columns = ['Upper 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
new_table.count()
# Out:
# Value                      128
# Year                       128
# Sex                        128
# Alcohol Specific Deaths    128
# Measure Type               128
# Unit                       128
# dtype: int64

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Upper 95% confidence limit']

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Lower 95% confidence limit']

# %%
Final_table = pd.merge(new_table, nt1, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(2)
# Out:
#    Value  Year      Sex  Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0   96.0  2001  Females                     Deaths          Count  People
# 1    6.8  2001  Females  Rate per 100,000 persons1          Count  People
#
#    Lower 95% confidence limit   Alcohol Specific Deaths_y Measure Type_y  \
# 0                         5.5  Lower 95% confidence limit          Count
# 1                         5.5  Lower 95% confidence limit          Count
#
#    Unit_y
# 0  People
# 1  People

# %%
Final_table = Final_table[['Value','Year','Sex','Alcohol Specific Deaths_x','Measure Type_x','Unit_x',
                           'Lower 95% confidence limit']]

# %%
Final_table = pd.merge(Final_table, nt2, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(1)
# Out:
#    Value  Year      Sex Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0   96.0  2001  Females                    Deaths          Count  People
#
#    Lower 95% confidence limit  Upper 95% confidence limit  \
# 0                         5.5                         8.3
#
#       Alcohol Specific Deaths Measure Type    Unit
# 0  Upper 95% confidence limit        Count  People

# %%
Final_table = Final_table[['Year','Sex','Alcohol Specific Deaths_x','Measure Type','Value','Lower 95% confidence limit', 'Upper 95% confidence limit','Unit']]

# %%
Final_table
# Out:
#     Year      Sex  Alcohol Specific Deaths_x Measure Type  Value  \
# 0   2001  Females                     Deaths        Count   96.0
# 1   2001  Females  Rate per 100,000 persons1        Count    6.8
# 2   2001    Males                     Deaths        Count  181.0
# 3   2001    Males  Rate per 100,000 persons1        Count   13.6
# 4   2002  Females                     Deaths        Count   89.0
# 5   2002  Females  Rate per 100,000 persons1        Count    6.2
# 6   2002    Males                     Deaths        Count  173.0
# 7   2002    Males  Rate per 100,000 persons1        Count   13.0
# 8   2003  Females                     Deaths        Count   93.0
# 9   2003  Females  Rate per 100,000 persons1        Count    6.4
# 10  2003    Males                     Deaths        Count  193.0
# 11  2003    Males  Rate per 100,000 persons1        Count   14.6
# 12  2004  Females                     Deaths        Count  115.0
# 13  2004  Females  Rate per 100,000 persons1        Count    7.8
# 14  2004    Males                     Deaths        Count  204.0
# 15  2004    Males  Rate per 100,000 persons1        Count   14.9
# 16  2005  Females                     Deaths        Count  114.0
# 17  2005  Females  Rate per 100,000 persons1        Count    7.7
# 18  2005    Males                     Deaths        Count  207.0
# 19  2005    Males  Rate per 100,000 persons1        Count   14.9
# 20  2006  Females                     Deaths        Count  122.0
# 21  2006  Females  Rate per 100,000 persons1        Count    8.3
# 22  2006    Males                     Deaths        Count  218.0
# 23  2006    Males  Rate per 100,000 persons1        Count   15.5
# 24  2007  Females                     Deaths        Count  118.0
# 25  2007  Females  Rate per 100,000 persons1        Count    7.9
# 26  2007    Males                     Deaths        Count  255.0
# 27  2007    Males  Rate per 100,000 persons1        Count   18.0
# 28  2008  Females                     Deaths        Count  148.0
# 29  2008  Females  Rate per 100,000 persons1        Count    9.9
# ..   ...      ...                        ...          ...    ...
# 34  2009    Males                     Deaths        Count  262.0
# 35  2009    Males  Rate per 100,000 persons1        Count   18.2
# 36  2010  Females                     Deaths        Count  137.0
# 37  2010  Females  Rate per 100,000 persons1        Count    9.0
# 38  2010    Males                     Deaths        Count  254.0
# 39  2010    Males  Rate per 100,000 persons1        Count   17.5
# 40  2011  Females                     Deaths        Count  129.0
# 41  2011  Females  Rate per 100,000 persons1        Count    8.3
# 42  2011    Males                     Deaths        Count  243.0
# 43  2011    Males  Rate per 100,000 persons1        Count   16.7
# 44  2012  Females                     Deaths        Count  149.0
# 45  2012  Females  Rate per 100,000 persons1        Count    9.6
# 46  2012    Males                     Deaths        Count  255.0
# 47  2012    Males  Rate per 100,000 persons1        Count   17.6
# 48  2013  Females                     Deaths        Count  133.0
# 49  2013  Females  Rate per 100,000 persons1        Count    8.6
# 50  2013    Males                     Deaths        Count  253.0
# 51  2013    Males  Rate per 100,000 persons1        Count   17.0
# 52  2014  Females                     Deaths        Count  121.0
# 53  2014  Females  Rate per 100,000 persons1        Count    7.7
# 54  2014    Males                     Deaths        Count  230.0
# 55  2014    Males  Rate per 100,000 persons1        Count   15.5
# 56  2015  Females                     Deaths        Count  132.0
# 57  2015  Females  Rate per 100,000 persons1        Count    8.5
# 58  2015    Males                     Deaths        Count  229.0
# 59  2015    Males  Rate per 100,000 persons1        Count   15.4
# 60  2016  Females                     Deaths        Count  130.0
# 61  2016  Females  Rate per 100,000 persons1        Count    8.3
# 62  2016    Males                     Deaths        Count  258.0
# 63  2016    Males  Rate per 100,000 persons1        Count   17.4
#
#     Lower 95% confidence limit  Upper 95% confidence limit    Unit
# 0                          5.5                         8.3  People
# 1                          5.5                         8.3  People
# 2                         11.6                        15.5  People
# 3                         11.6                        15.5  People
# 4                          5.0                         7.6  People
# 5                          5.0                         7.6  People
# 6                         11.1                        15.0  People
# 7                         11.1                        15.0  People
# 8                          5.2                         7.9  People
# 9                          5.2                         7.9  People
# 10                        12.5                        16.6  People
# 11                        12.5                        16.6  People
# 12                         6.4                         9.3  People
# 13                         6.4                         9.3  People
# 14                        12.9                        17.0  People
# 15                        12.9                        17.0  People
# 16                         6.3                         9.2  People
# 17                         6.3                         9.2  People
# 18                        12.9                        17.0  People
# 19                        12.9                        17.0  People
# 20                         6.8                         9.7  People
# 21                         6.8                         9.7  People
# 22                        13.5                        17.6  People
# 23                        13.5                        17.6  People
# 24                         6.5                         9.4  People
# 25                         6.5                         9.4  People
# 26                        15.8                        20.2  People
# 27                        15.8                        20.2  People
# 28                         8.3                        11.5  People
# 29                         8.3                        11.5  People
# ..                         ...                         ...     ...
# 34                        16.0                        20.5  People
# 35                        16.0                        20.5  People
# 36                         7.5                        10.5  People
# 37                         7.5                        10.5  People
# 38                        15.4                        19.7  People
# 39                        15.4                        19.7  People
# 40                         6.9                         9.7  People
# 41                         6.9                         9.7  People
# 42                        14.6                        18.8  People
# 43                        14.6                        18.8  People
# 44                         8.1                        11.2  People
# 45                         8.1                        11.2  People
# 46                        15.4                        19.7  People
# 47                        15.4                        19.7  People
# 48                         7.1                        10.1  People
# 49                         7.1                        10.1  People
# 50                        14.9                        19.1  People
# 51                        14.9                        19.1  People
# 52                         6.3                         9.1  People
# 53                         6.3                         9.1  People
# 54                        13.5                        17.5  People
# 55                        13.5                        17.5  People
# 56                         7.0                         9.9  People
# 57                         7.0                         9.9  People
# 58                        13.4                        17.4  People
# 59                        13.4                        17.4  People
# 60                         6.9                         9.8  People
# 61                         6.9                         9.8  People
# 62                        15.2                        19.5  People
# 63                        15.2                        19.5  People
#
# [64 rows x 8 columns]

# %%
Final_table.columns = ['Alcohol Specific Deaths' if x=='Alcohol Specific Deaths_x' else x for x in Final_table.columns]

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Lower 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Lower 95% confidence limit']), axis = 1)

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Upper 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Upper 95% confidence limit']), axis = 1)

# %%
Final_table['Alcohol Specific Deaths'] = Final_table['Alcohol Specific Deaths'].str.rstrip('1')

# %%
Final_table['Sex'] = Final_table['Sex'].map(
    lambda x: {
        'All persons' : 'T', 
        'Males' : 'M',
        'Females': 'F'         
        }.get(x, x))

# %%
Final_table['Age'] =  'All'

# %%
Final_table['Geography'] =  'W92000004'
