# %% [markdown]
# Table 7: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in Wales, 2001 to 2016

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/healthandsocialcare/causesofdeath/datasets/alcoholspecificdeathsintheukmaindataset')
    sheet = scraper.distribution().as_databaker()
# Out:
# WARNING:Unexpected "next release" field: Unknown string format

# %%
tab = next(tab for tab in sheet if tab.name=='Table 7')

# %%
observations = tab.excel_ref('D7').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<J17 8.3>, <N8 173.0>, <I20 121.0>, <E14 14.6>, <P8 11.1>, <I16 137.0>, <E11 11.2>, <O8 13.0>, <D18 404.0>, <D22 388.0>, <D20 351.0>, <K22 6.9>, <I18 149.0>, <Q11 17.0>, <E8 9.5>, <K20 6.3>, <O11 14.9>, <G20 12.7>, <F8 8.3>, <Q13 20.2>, <J18 9.6>, <G22 14.0>, <E7 10.1>, <J14 9.9>, <G8 10.6>, <N22 258.0>, <N17 243.0>, <O21 15.4>, <K12 6.8>, <D23 419.0>, <E23 13.5>, <P20 13.5>, <I9 93.0>, <F15 11.6>, <G16 14.5>, <L10 9.3>, <E9 10.3>, <Q12 17.6>, <L14 11.5>, <D7 277.0>, <P12 13.5>, <Q22 19.5>, <L22 9.8>, <I8 89.0>, <F17 11.1>, <K9 5.2>, <J7 6.8>, <K16 7.5>, <L20 9.1>, <D17 372.0>, <P10 12.9>, <J10 7.8>, <I12 122.0>, <E18 13.5>, <G21 13.1>, <G15 14.2>, <P7 11.6>, <L18 11.2>, <Q8 15.0>, <E16 13.1>, <F7 8.9>, <I11 114.0>, <Q23 20.1>, <O10 14.9>, <F18 12.1>, <K15 6.5>, <L9 7.9>, <D21 361.0>, <E22 12.7>, <L16 10.5>, <Q20 17.5>, <L8 7.6>, <L13 9.4>, <K11 6.3>, <Q14 21.9>, <Q18 19.7>, <F16 11.8>, <P14 17.3>, <P23 15.8>, <O19 17.0>, <N14 278.0>, <J21 8.5>, <G11 12.4>, <N7 181.0>, <J19 8.6>, <E10 11.3>, <O16 17.5>, <I22 130.0>, <G19 14.0>, <P15 16.0>, <I15 121.0>, <O15 18.2>, <J11 7.7>, <F21 10.6>, <J20 7.7>, <D14 426.0>, <N9 193.0>, <E20 11.5>, <E13 12.8>, <F10 10.1>, <J15 7.9>, <Q7 15.5>, <Q21 17.4>, <F9 9.1>, <I7 96.0>, <N21 229.0>, <O7 13.6>, <I23 148.0>, <O22 17.4>, <G14 16.0>, <I10 115.0>, <N15 262.0>, <E12 11.8>, <P22 15.2>, <D9 286.0>, <Q10 17.0>, <G13 14.1>, <I21 132.0>, <K7 5.5>, <I14 148.0>, <J9 6.4>, <Q17 18.8>, <P13 15.8>, <F22 11.4>, <J23 9.2>, <F23 12.2>, <G23 14.8>, <L19 10.1>, <I13 118.0>, <D16 391.0>, <F14 13.2>, <Q9 16.6>, <I17 129.0>, <G7 11.3>, <K13 6.5>, <P19 14.9>, <O14 19.6>, <K19 7.1>, <O18 17.6>, <P21 13.4>, <N19 253.0>, <K21 7.0>, <L11 9.2>, <N12 218.0>, <N23 271.0>, <N20 230.0>, <E19 12.7>, <I19 133.0>, <Q19 19.1>, <N18 255.0>, <L21 9.9>, <G12 13.1>, <J16 9.0>, <D15 383.0>, <K18 8.1>, <J8 6.2>, <K14 8.3>, <K17 6.9>, <L15 9.4>, <P11 12.9>, <O13 18.0>, <G18 14.8>, <F12 10.6>, <N10 204.0>, <J13 7.9>, <Q15 20.5>, <K8 5.0>, <O12 15.5>, <F11 9.9>, <P16 15.4>, <D13 373.0>, <O9 14.6>, <N16 254.0>, <O17 16.7>, <J12 8.3>, <F20 10.3>, <L12 9.7>, <E15 12.9>, <K10 6.4>, <G10 12.6>, <D19 386.0>, <D11 321.0>, <N11 207.0>, <L17 9.7>, <P18 15.4>, <D8 262.0>, <F13 11.5>, <E21 11.9>, <J22 8.3>, <G17 13.6>, <D12 340.0>, <L23 10.7>, <F19 11.4>, <G9 11.5>, <P17 14.6>, <Q16 19.7>, <K23 7.7>, <O23 18.0>, <O20 15.5>, <N13 255.0>, <L7 8.3>, <D10 319.0>, <E17 12.4>, <P9 12.5>}

# %%
Sex = tab.excel_ref('D5').expand(RIGHT).is_not_whitespace()
Sex
# Out:
# {<I5 'Females'>, <D5 'All Persons'>, <N5 'Males'>}

# %%
deaths = tab.excel_ref('D6').expand(RIGHT).is_not_blank()
deaths
# Out:
# {<L6 'Upper 95% confidence limit'>, <G6 'Upper 95% confidence limit'>, <D6 'Deaths'>, <N6 'Deaths'>, <E6 'Rate per 100,000 people1'>, <I6 'Deaths'>, <P6 'Lower 95% confidence limit'>, <K6 'Lower 95% confidence limit'>, <J6 'Rate per 100,000 females1'>, <Q6 'Upper 95% confidence limit'>, <O6 'Rate per 100,000 males1'>, <F6 'Lower 95% confidence limit'>}

# %%
# lc = tab.excel_ref('D6').expand(RIGHT).filter(contains_string('Lower 95% confidence limit'))
# lc

# %%
# uc = tab.excel_ref('F6').expand(RIGHT).filter(contains_string('Upper 95% confidence limit'))
# uc

# %%
Year = tab.excel_ref('B7').expand(DOWN) - tab.excel_ref('A24').expand(DOWN)  
Year
# Out:
# {<B27 '1 Age-standardised rates are expressed per 100,000 population, standardised to the 2013 European Standard Population.'>, <B10 2004.0>, <B17 2011.0>, <B23 2017.0>, <B29 '3 Figures are for deaths registered in each calendar year.'>, <B8 2002.0>, <B21 2015.0>, <B7 2001.0>, <B19 2013.0>, <B22 2016.0>, <B24 'Source: Office for National Statistics'>, <B33 ''>, <B15 2009.0>, <B25 ''>, <B30 '4 The lower and upper confidence limits have been provided. These form a confidence interval, which is a measure of the statistical precision of an estimate and shows the range of uncertainty around the estimated figure. Calculations based on small numbers of events are often subject to random fluctuations. As a general rule, if the confidence interval around one figure overlaps with the interval around another, we cannot say with certainty that there is more than a chance difference between the two figures.'>, <B13 2007.0>, <B20 2014.0>, <B18 2012.0>, <B26 'Notes:'>, <B11 2005.0>, <B14 2008.0>, <B31 ''>, <B12 2006.0>, <B28 '2 Deaths of non-residents are excluded in figures for Wales.'>, <B32 ''>, <B16 2010.0>, <B9 2003.0>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(Sex,'Sex',CLOSEST,LEFT),
            HDim(deaths, 'Alcohol Specific Deaths',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Sex</td><td class="xc3" style="background-color:LightGray">Alcohol Specific Deaths</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 7</caption>
# <tr><td title="0 0"></td><td title="1 0">Back to contents</td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td><td title="11 0"></td><td title="12 0"></td><td title="13 0"></td><td title="14 0"></td><td title="15 0"></td><td title="16 0"></td></tr>
# <tr><td title="0 1"></td><td style="font-weight:bold" title="1 1">Table 7: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in Wales, 2001 to 20171,2,3,4</td><td style="font-weight:bold" title="2 1"></td><td style="font-weight:bold" title="3 1"></td><td style="font-weight:bold" title="4 1"></td><td style="font-weight:bold" title="5 1"></td><td style="font-weight:bold" title="6 1"></td><td style="font-weight:bold" title="7 1"></td><td style="font-weight:bold" title="8 1"></td><td style="font-weight:bold" title="9 1"></td><td style="font-weight:bold" title="10 1"></td><td style="font-weight:bold" title="11 1"></td><td style="font-weight:bold" title="12 1"></td><td style="font-weight:bold" title="13 1"></td><td style="font-weight:bold" title="14 1"></td><td style="font-weight:bold" title="15 1"></td><td style="font-weight:bold" title="16 1"></td></tr>
# <tr><td title="0 2"></td><td style="font-weight:bold" title="1 2"></td><td style="font-weight:bold" title="2 2"></td><td style="font-weight:bold" title="3 2"></td><td style="font-weight:bold" title="4 2"></td><td style="font-weight:bold" title="5 2"></td><td style="font-weight:bold" title="6 2"></td><td style="font-weight:bold" title="7 2"></td><td style="font-weight:bold" title="8 2"></td><td style="font-weight:bold" title="9 2"></td><td style="font-weight:bold" title="10 2"></td><td style="font-weight:bold" title="11 2"></td><td style="font-weight:bold" title="12 2"></td><td style="font-weight:bold" title="13 2"></td><td style="font-weight:bold" title="14 2"></td><td style="font-weight:bold" title="15 2"></td><td style="font-weight:bold" title="16 2"></td></tr>
# <tr><td title="0 3"></td><td style="font-weight:bold" title="1 3"></td><td style="font-weight:bold" title="2 3"></td><td style="font-weight:bold" title="3 3"></td><td style="font-weight:bold" title="4 3"></td><td style="font-weight:bold" title="5 3"></td><td style="font-weight:bold" title="6 3"></td><td style="font-weight:bold" title="7 3"></td><td title="8 3"></td><td title="9 3"></td><td title="10 3"></td><td title="11 3"></td><td title="12 3"></td><td title="13 3"></td><td title="14 3"></td><td title="15 3"></td><td title="16 3"></td></tr>
# <tr><td title="0 4"></td><td style="font-weight:bold" title="1 4"></td><td style="font-weight:bold" title="2 4"></td><td style="background-color:MistyRose;font-weight:bold" title="3 4">All Persons</td><td style="font-weight:bold" title="4 4"></td><td style="font-weight:bold" title="5 4"></td><td style="font-weight:bold" title="6 4"></td><td style="font-weight:bold" title="7 4"></td><td style="background-color:MistyRose;font-weight:bold" title="8 4">Females</td><td style="font-weight:bold" title="9 4"></td><td style="font-weight:bold" title="10 4"></td><td style="font-weight:bold" title="11 4"></td><td title="12 4"></td><td style="background-color:MistyRose;font-weight:bold" title="13 4">Males</td><td style="font-weight:bold" title="14 4"></td><td style="font-weight:bold" title="15 4"></td><td style="font-weight:bold" title="16 4"></td></tr>
# <tr><td title="0 5"></td><td style="font-weight:bold" title="1 5">Year</td><td style="font-weight:bold" title="2 5"></td><td style="background-color:LightGray;font-weight:bold" title="3 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="4 5">Rate per 100,000 people1</td><td style="background-color:LightGray;font-weight:bold" title="5 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="6 5">Upper 95% confidence limit</td><td title="7 5"></td><td style="background-color:LightGray;font-weight:bold" title="8 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="9 5">Rate per 100,000 females1</td><td style="background-color:LightGray;font-weight:bold" title="10 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="11 5">Upper 95% confidence limit</td><td title="12 5"></td><td style="background-color:LightGray;font-weight:bold" title="13 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="14 5">Rate per 100,000 males1</td><td style="background-color:LightGray;font-weight:bold" title="15 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="16 5">Upper 95% confidence limit</td></tr>
# <tr><td title="0 6"></td><td style="background-color:LightGreen" title="1 6">2001.0</td><td title="2 6"></td><td style="background-color:Aqua" title="3 6">277.0</td><td style="background-color:Aqua" title="4 6">10.1</td><td style="background-color:Aqua" title="5 6">8.9</td><td style="background-color:Aqua" title="6 6">11.3</td><td title="7 6"></td><td style="background-color:Aqua" title="8 6">96.0</td><td style="background-color:Aqua" title="9 6">6.8</td><td style="background-color:Aqua" title="10 6">5.5</td><td style="background-color:Aqua" title="11 6">8.3</td><td title="12 6"></td><td style="background-color:Aqua" title="13 6">181.0</td><td style="background-color:Aqua" title="14 6">13.6</td><td style="background-color:Aqua" title="15 6">11.6</td><td style="background-color:Aqua" title="16 6">15.5</td></tr>
# <tr><td title="0 7"></td><td style="background-color:LightGreen" title="1 7">2002.0</td><td title="2 7"></td><td style="background-color:Aqua" title="3 7">262.0</td><td style="background-color:Aqua" title="4 7">9.5</td><td style="background-color:Aqua" title="5 7">8.3</td><td style="background-color:Aqua" title="6 7">10.6</td><td title="7 7"></td><td style="background-color:Aqua" title="8 7">89.0</td><td style="background-color:Aqua" title="9 7">6.2</td><td style="background-color:Aqua" title="10 7">5.0</td><td style="background-color:Aqua" title="11 7">7.6</td><td title="12 7"></td><td style="background-color:Aqua" title="13 7">173.0</td><td style="background-color:Aqua" title="14 7">13.0</td><td style="background-color:Aqua" title="15 7">11.1</td><td style="background-color:Aqua" title="16 7">15.0</td></tr>
# <tr><td title="0 8"></td><td style="background-color:LightGreen" title="1 8">2003.0</td><td title="2 8"></td><td style="background-color:Aqua" title="3 8">286.0</td><td style="background-color:Aqua" title="4 8">10.3</td><td style="background-color:Aqua" title="5 8">9.1</td><td style="background-color:Aqua" title="6 8">11.5</td><td title="7 8"></td><td style="background-color:Aqua" title="8 8">93.0</td><td style="background-color:Aqua" title="9 8">6.4</td><td style="background-color:Aqua" title="10 8">5.2</td><td style="background-color:Aqua" title="11 8">7.9</td><td title="12 8"></td><td style="background-color:Aqua" title="13 8">193.0</td><td style="background-color:Aqua" title="14 8">14.6</td><td style="background-color:Aqua" title="15 8">12.5</td><td style="background-color:Aqua" title="16 8">16.6</td></tr>
# <tr><td title="0 9"></td><td style="background-color:LightGreen" title="1 9">2004.0</td>

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS    Year          Sex     Alcohol Specific Deaths Measure Type  \
# 0    277.0  2001.0  All Persons                      Deaths        Count
# 1     10.1  2001.0  All Persons    Rate per 100,000 people1        Count
# 2      8.9  2001.0  All Persons  Lower 95% confidence limit        Count
# 3     11.3  2001.0  All Persons  Upper 95% confidence limit        Count
# 4     96.0  2001.0      Females                      Deaths        Count
# 5      6.8  2001.0      Females   Rate per 100,000 females1        Count
# 6      5.5  2001.0      Females  Lower 95% confidence limit        Count
# 7      8.3  2001.0      Females  Upper 95% confidence limit        Count
# 8    181.0  2001.0        Males                      Deaths        Count
# 9     13.6  2001.0        Males     Rate per 100,000 males1        Count
# 10    11.6  2001.0        Males  Lower 95% confidence limit        Count
# 11    15.5  2001.0        Males  Upper 95% confidence limit        Count
# 12   262.0  2002.0  All Persons                      Deaths        Count
# 13     9.5  2002.0  All Persons    Rate per 100,000 people1        Count
# 14     8.3  2002.0  All Persons  Lower 95% confidence limit        Count
# 15    10.6  2002.0  All Persons  Upper 95% confidence limit        Count
# 16    89.0  2002.0      Females                      Deaths        Count
# 17     6.2  2002.0      Females   Rate per 100,000 females1        Count
# 18     5.0  2002.0      Females  Lower 95% confidence limit        Count
# 19     7.6  2002.0      Females  Upper 95% confidence limit        Count
# 20   173.0  2002.0        Males                      Deaths        Count
# 21    13.0  2002.0        Males     Rate per 100,000 males1        Count
# 22    11.1  2002.0        Males  Lower 95% confidence limit        Count
# 23    15.0  2002.0        Males  Upper 95% confidence limit        Count
# 24   286.0  2003.0  All Persons                      Deaths        Count
# 25    10.3  2003.0  All Persons    Rate per 100,000 people1        Count
# 26     9.1  2003.0  All Persons  Lower 95% confidence limit        Count
# 27    11.5  2003.0  All Persons  Upper 95% confidence limit        Count
# 28    93.0  2003.0      Females                      Deaths        Count
# 29     6.4  2003.0      Females   Rate per 100,000 females1        Count
# ..     ...     ...          ...                         ...          ...
# 174    7.0  2015.0      Females  Lower 95% confidence limit        Count
# 175    9.9  2015.0      Females  Upper 95% confidence limit        Count
# 176  229.0  2015.0        Males                      Deaths        Count
# 177   15.4  2015.0        Males     Rate per 100,000 males1        Count
# 178   13.4  2015.0        Males  Lower 95% confidence limit        Count
# 179   17.4  2015.0        Males  Upper 95% confidence limit        Count
# 180  388.0  2016.0  All Persons                      Deaths        Count
# 181   12.7  2016.0  All Persons    Rate per 100,000 people1        Count
# 182   11.4  2016.0  All Persons  Lower 95% confidence limit        Count
# 183   14.0  2016.0  All Persons  Upper 95% confidence limit        Count
# 184  130.0  2016.0      Females                      Deaths        Count
# 185    8.3  2016.0      Females   Rate per 100,000 females1        Count
# 186    6.9  2016.0      Females  Lower 95% confidence limit        Count
# 187    9.8  2016.0      Females  Upper 95% confidence limit        Count
# 188  258.0  2016.0        Males                      Deaths        Count
# 189   17.4  2016.0        Males     Rate per 100,000 males1        Count
# 190   15.2  2016.0        Males  Lower 95% confidence limit        Count
# 191   19.5  2016.0        Males  Upper 95% confidence limit        Count
# 192  419.0  2017.0  All Persons                      Deaths        Count
# 193   13.5  2017.0  All Persons    Rate per 100,000 people1        Count
# 194   12.2  2017.0  All Persons  Lower 95% confidence limit        Count
# 195   14.8  2017.0  All Persons  Upper 95% confidence limit        Count
# 196  148.0  2017.0      Females                      Deaths        Count
# 197    9.2  2017.0      Females   Rate per 100,000 females1        Count
# 198    7.7  2017.0      Females  Lower 95% confidence limit        Count
# 199   10.7  2017.0      Females  Upper 95% confidence limit        Count
# 200  271.0  2017.0        Males                      Deaths        Count
# 201   18.0  2017.0        Males     Rate per 100,000 males1        Count
# 202   15.8  2017.0        Males  Lower 95% confidence limit        Count
# 203   20.1  2017.0        Males  Upper 95% confidence limit        Count
#
#        Unit
# 0    People
# 1    People
# 2    People
# 3    People
# 4    People
# 5    People
# 6    People
# 7    People
# 8    People
# 9    People
# 10   People
# 11   People
# 12   People
# 13   People
# 14   People
# 15   People
# 16   People
# 17   People
# 18   People
# 19   People
# 20   People
# 21   People
# 22   People
# 23   People
# 24   People
# 25   People
# 26   People
# 27   People
# 28   People
# 29   People
# ..      ...
# 174  People
# 175  People
# 176  People
# 177  People
# 178  People
# 179  People
# 180  People
# 181  People
# 182  People
# 183  People
# 184  People
# 185  People
# 186  People
# 187  People
# 188  People
# 189  People
# 190  People
# 191  People
# 192  People
# 193  People
# 194  People
# 195  People
# 196  People
# 197  People
# 198  People
# 199  People
# 200  People
# 201  People
# 202  People
# 203  People
#
# [204 rows x 6 columns]

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
# new_table['Year'] = new_table['Year'].astype(str)

# %%
# new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value                      float64
# Year                         int32
# Sex                         object
# Alcohol Specific Deaths     object
# Measure Type                object
# Unit                        object
# dtype: object

# %%
new_table
# Out:
#      Value  Year          Sex     Alcohol Specific Deaths Measure Type    Unit
# 0    277.0  2001  All Persons                      Deaths        Count  People
# 1     10.1  2001  All Persons    Rate per 100,000 people1        Count  People
# 2      8.9  2001  All Persons  Lower 95% confidence limit        Count  People
# 3     11.3  2001  All Persons  Upper 95% confidence limit        Count  People
# 4     96.0  2001      Females                      Deaths        Count  People
# 5      6.8  2001      Females   Rate per 100,000 females1        Count  People
# 6      5.5  2001      Females  Lower 95% confidence limit        Count  People
# 7      8.3  2001      Females  Upper 95% confidence limit        Count  People
# 8    181.0  2001        Males                      Deaths        Count  People
# 9     13.6  2001        Males     Rate per 100,000 males1        Count  People
# 10    11.6  2001        Males  Lower 95% confidence limit        Count  People
# 11    15.5  2001        Males  Upper 95% confidence limit        Count  People
# 12   262.0  2002  All Persons                      Deaths        Count  People
# 13     9.5  2002  All Persons    Rate per 100,000 people1        Count  People
# 14     8.3  2002  All Persons  Lower 95% confidence limit        Count  People
# 15    10.6  2002  All Persons  Upper 95% confidence limit        Count  People
# 16    89.0  2002      Females                      Deaths        Count  People
# 17     6.2  2002      Females   Rate per 100,000 females1        Count  People
# 18     5.0  2002      Females  Lower 95% confidence limit        Count  People
# 19     7.6  2002      Females  Upper 95% confidence limit        Count  People
# 20   173.0  2002        Males                      Deaths        Count  People
# 21    13.0  2002        Males     Rate per 100,000 males1        Count  People
# 22    11.1  2002        Males  Lower 95% confidence limit        Count  People
# 23    15.0  2002        Males  Upper 95% confidence limit        Count  People
# 24   286.0  2003  All Persons                      Deaths        Count  People
# 25    10.3  2003  All Persons    Rate per 100,000 people1        Count  People
# 26     9.1  2003  All Persons  Lower 95% confidence limit        Count  People
# 27    11.5  2003  All Persons  Upper 95% confidence limit        Count  People
# 28    93.0  2003      Females                      Deaths        Count  People
# 29     6.4  2003      Females   Rate per 100,000 females1        Count  People
# ..     ...   ...          ...                         ...          ...     ...
# 174    7.0  2015      Females  Lower 95% confidence limit        Count  People
# 175    9.9  2015      Females  Upper 95% confidence limit        Count  People
# 176  229.0  2015        Males                      Deaths        Count  People
# 177   15.4  2015        Males     Rate per 100,000 males1        Count  People
# 178   13.4  2015        Males  Lower 95% confidence limit        Count  People
# 179   17.4  2015        Males  Upper 95% confidence limit        Count  People
# 180  388.0  2016  All Persons                      Deaths        Count  People
# 181   12.7  2016  All Persons    Rate per 100,000 people1        Count  People
# 182   11.4  2016  All Persons  Lower 95% confidence limit        Count  People
# 183   14.0  2016  All Persons  Upper 95% confidence limit        Count  People
# 184  130.0  2016      Females                      Deaths        Count  People
# 185    8.3  2016      Females   Rate per 100,000 females1        Count  People
# 186    6.9  2016      Females  Lower 95% confidence limit        Count  People
# 187    9.8  2016      Females  Upper 95% confidence limit        Count  People
# 188  258.0  2016        Males                      Deaths        Count  People
# 189   17.4  2016        Males     Rate per 100,000 males1        Count  People
# 190   15.2  2016        Males  Lower 95% confidence limit        Count  People
# 191   19.5  2016        Males  Upper 95% confidence limit        Count  People
# 192  419.0  2017  All Persons                      Deaths        Count  People
# 193   13.5  2017  All Persons    Rate per 100,000 people1        Count  People
# 194   12.2  2017  All Persons  Lower 95% confidence limit        Count  People
# 195   14.8  2017  All Persons  Upper 95% confidence limit        Count  People
# 196  148.0  2017      Females                      Deaths        Count  People
# 197    9.2  2017      Females   Rate per 100,000 females1        Count  People
# 198    7.7  2017      Females  Lower 95% confidence limit        Count  People
# 199   10.7  2017      Females  Upper 95% confidence limit        Count  People
# 200  271.0  2017        Males                      Deaths        Count  People
# 201   18.0  2017        Males     Rate per 100,000 males1        Count  People
# 202   15.8  2017        Males  Lower 95% confidence limit        Count  People
# 203   20.1  2017        Males  Upper 95% confidence limit        Count  People
#
# [204 rows x 6 columns]

# %%
nt1 = new_table[new_table['Alcohol Specific Deaths'] == 'Lower 95% confidence limit']

# %%
nt1
# Out:
#      Value  Year          Sex     Alcohol Specific Deaths Measure Type    Unit
# 2      8.9  2001  All Persons  Lower 95% confidence limit        Count  People
# 6      5.5  2001      Females  Lower 95% confidence limit        Count  People
# 10    11.6  2001        Males  Lower 95% confidence limit        Count  People
# 14     8.3  2002  All Persons  Lower 95% confidence limit        Count  People
# 18     5.0  2002      Females  Lower 95% confidence limit        Count  People
# 22    11.1  2002        Males  Lower 95% confidence limit        Count  People
# 26     9.1  2003  All Persons  Lower 95% confidence limit        Count  People
# 30     5.2  2003      Females  Lower 95% confidence limit        Count  People
# 34    12.5  2003        Males  Lower 95% confidence limit        Count  People
# 38    10.1  2004  All Persons  Lower 95% confidence limit        Count  People
# 42     6.4  2004      Females  Lower 95% confidence limit        Count  People
# 46    12.9  2004        Males  Lower 95% confidence limit        Count  People
# 50     9.9  2005  All Persons  Lower 95% confidence limit        Count  People
# 54     6.3  2005      Females  Lower 95% confidence limit        Count  People
# 58    12.9  2005        Males  Lower 95% confidence limit        Count  People
# 62    10.6  2006  All Persons  Lower 95% confidence limit        Count  People
# 66     6.8  2006      Females  Lower 95% confidence limit        Count  People
# 70    13.5  2006        Males  Lower 95% confidence limit        Count  People
# 74    11.5  2007  All Persons  Lower 95% confidence limit        Count  People
# 78     6.5  2007      Females  Lower 95% confidence limit        Count  People
# 82    15.8  2007        Males  Lower 95% confidence limit        Count  People
# 86    13.2  2008  All Persons  Lower 95% confidence limit        Count  People
# 90     8.3  2008      Females  Lower 95% confidence limit        Count  People
# 94    17.3  2008        Males  Lower 95% confidence limit        Count  People
# 98    11.6  2009  All Persons  Lower 95% confidence limit        Count  People
# 102    6.5  2009      Females  Lower 95% confidence limit        Count  People
# 106   16.0  2009        Males  Lower 95% confidence limit        Count  People
# 110   11.8  2010  All Persons  Lower 95% confidence limit        Count  People
# 114    7.5  2010      Females  Lower 95% confidence limit        Count  People
# 118   15.4  2010        Males  Lower 95% confidence limit        Count  People
# 122   11.1  2011  All Persons  Lower 95% confidence limit        Count  People
# 126    6.9  2011      Females  Lower 95% confidence limit        Count  People
# 130   14.6  2011        Males  Lower 95% confidence limit        Count  People
# 134   12.1  2012  All Persons  Lower 95% confidence limit        Count  People
# 138    8.1  2012      Females  Lower 95% confidence limit        Count  People
# 142   15.4  2012        Males  Lower 95% confidence limit        Count  People
# 146   11.4  2013  All Persons  Lower 95% confidence limit        Count  People
# 150    7.1  2013      Females  Lower 95% confidence limit        Count  People
# 154   14.9  2013        Males  Lower 95% confidence limit        Count  People
# 158   10.3  2014  All Persons  Lower 95% confidence limit        Count  People
# 162    6.3  2014      Females  Lower 95% confidence limit        Count  People
# 166   13.5  2014        Males  Lower 95% confidence limit        Count  People
# 170   10.6  2015  All Persons  Lower 95% confidence limit        Count  People
# 174    7.0  2015      Females  Lower 95% confidence limit        Count  People
# 178   13.4  2015        Males  Lower 95% confidence limit        Count  People
# 182   11.4  2016  All Persons  Lower 95% confidence limit        Count  People
# 186    6.9  2016      Females  Lower 95% confidence limit        Count  People
# 190   15.2  2016        Males  Lower 95% confidence limit        Count  People
# 194   12.2  2017  All Persons  Lower 95% confidence limit        Count  People
# 198    7.7  2017      Females  Lower 95% confidence limit        Count  People
# 202   15.8  2017        Males  Lower 95% confidence limit        Count  People

# %%
nt1.columns = ['Lower 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
nt2 = new_table[new_table['Alcohol Specific Deaths'] == 'Upper 95% confidence limit']

# %%
nt2
# Out:
#      Value  Year          Sex     Alcohol Specific Deaths Measure Type    Unit
# 3     11.3  2001  All Persons  Upper 95% confidence limit        Count  People
# 7      8.3  2001      Females  Upper 95% confidence limit        Count  People
# 11    15.5  2001        Males  Upper 95% confidence limit        Count  People
# 15    10.6  2002  All Persons  Upper 95% confidence limit        Count  People
# 19     7.6  2002      Females  Upper 95% confidence limit        Count  People
# 23    15.0  2002        Males  Upper 95% confidence limit        Count  People
# 27    11.5  2003  All Persons  Upper 95% confidence limit        Count  People
# 31     7.9  2003      Females  Upper 95% confidence limit        Count  People
# 35    16.6  2003        Males  Upper 95% confidence limit        Count  People
# 39    12.6  2004  All Persons  Upper 95% confidence limit        Count  People
# 43     9.3  2004      Females  Upper 95% confidence limit        Count  People
# 47    17.0  2004        Males  Upper 95% confidence limit        Count  People
# 51    12.4  2005  All Persons  Upper 95% confidence limit        Count  People
# 55     9.2  2005      Females  Upper 95% confidence limit        Count  People
# 59    17.0  2005        Males  Upper 95% confidence limit        Count  People
# 63    13.1  2006  All Persons  Upper 95% confidence limit        Count  People
# 67     9.7  2006      Females  Upper 95% confidence limit        Count  People
# 71    17.6  2006        Males  Upper 95% confidence limit        Count  People
# 75    14.1  2007  All Persons  Upper 95% confidence limit        Count  People
# 79     9.4  2007      Females  Upper 95% confidence limit        Count  People
# 83    20.2  2007        Males  Upper 95% confidence limit        Count  People
# 87    16.0  2008  All Persons  Upper 95% confidence limit        Count  People
# 91    11.5  2008      Females  Upper 95% confidence limit        Count  People
# 95    21.9  2008        Males  Upper 95% confidence limit        Count  People
# 99    14.2  2009  All Persons  Upper 95% confidence limit        Count  People
# 103    9.4  2009      Females  Upper 95% confidence limit        Count  People
# 107   20.5  2009        Males  Upper 95% confidence limit        Count  People
# 111   14.5  2010  All Persons  Upper 95% confidence limit        Count  People
# 115   10.5  2010      Females  Upper 95% confidence limit        Count  People
# 119   19.7  2010        Males  Upper 95% confidence limit        Count  People
# 123   13.6  2011  All Persons  Upper 95% confidence limit        Count  People
# 127    9.7  2011      Females  Upper 95% confidence limit        Count  People
# 131   18.8  2011        Males  Upper 95% confidence limit        Count  People
# 135   14.8  2012  All Persons  Upper 95% confidence limit        Count  People
# 139   11.2  2012      Females  Upper 95% confidence limit        Count  People
# 143   19.7  2012        Males  Upper 95% confidence limit        Count  People
# 147   14.0  2013  All Persons  Upper 95% confidence limit        Count  People
# 151   10.1  2013      Females  Upper 95% confidence limit        Count  People
# 155   19.1  2013        Males  Upper 95% confidence limit        Count  People
# 159   12.7  2014  All Persons  Upper 95% confidence limit        Count  People
# 163    9.1  2014      Females  Upper 95% confidence limit        Count  People
# 167   17.5  2014        Males  Upper 95% confidence limit        Count  People
# 171   13.1  2015  All Persons  Upper 95% confidence limit        Count  People
# 175    9.9  2015      Females  Upper 95% confidence limit        Count  People
# 179   17.4  2015        Males  Upper 95% confidence limit        Count  People
# 183   14.0  2016  All Persons  Upper 95% confidence limit        Count  People
# 187    9.8  2016      Females  Upper 95% confidence limit        Count  People
# 191   19.5  2016        Males  Upper 95% confidence limit        Count  People
# 195   14.8  2017  All Persons  Upper 95% confidence limit        Count  People
# 199   10.7  2017      Females  Upper 95% confidence limit        Count  People
# 203   20.1  2017        Males  Upper 95% confidence limit        Count  People

# %%
nt2.columns = ['Upper 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
new_table.count()
# Out:
# Value                      204
# Year                       204
# Sex                        204
# Alcohol Specific Deaths    204
# Measure Type               204
# Unit                       204
# dtype: int64

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Upper 95% confidence limit']

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Lower 95% confidence limit']

# %%
Final_table = pd.merge(new_table, nt1, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(2)
# Out:
#    Value  Year          Sex Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0  277.0  2001  All Persons                    Deaths          Count  People
# 1   10.1  2001  All Persons  Rate per 100,000 people1          Count  People
#
#    Lower 95% confidence limit   Alcohol Specific Deaths_y Measure Type_y  \
# 0                         8.9  Lower 95% confidence limit          Count
# 1                         8.9  Lower 95% confidence limit          Count
#
#    Unit_y
# 0  People
# 1  People

# %%
Final_table = Final_table[['Value','Year','Sex','Alcohol Specific Deaths_x','Measure Type_x','Unit_x',
                           'Lower 95% confidence limit']]

# %%
Final_table = pd.merge(Final_table, nt2, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(1)
# Out:
#    Value  Year          Sex Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0  277.0  2001  All Persons                    Deaths          Count  People
#
#    Lower 95% confidence limit  Upper 95% confidence limit  \
# 0                         8.9                        11.3
#
#       Alcohol Specific Deaths Measure Type    Unit
# 0  Upper 95% confidence limit        Count  People

# %%
Final_table = Final_table[['Year','Sex','Alcohol Specific Deaths_x','Measure Type','Value','Lower 95% confidence limit', 'Upper 95% confidence limit','Unit']]

# %%
Final_table
# Out:
#      Year          Sex  Alcohol Specific Deaths_x Measure Type  Value  \
# 0    2001  All Persons                     Deaths        Count  277.0
# 1    2001  All Persons   Rate per 100,000 people1        Count   10.1
# 2    2001      Females                     Deaths        Count   96.0
# 3    2001      Females  Rate per 100,000 females1        Count    6.8
# 4    2001        Males                     Deaths        Count  181.0
# 5    2001        Males    Rate per 100,000 males1        Count   13.6
# 6    2002  All Persons                     Deaths        Count  262.0
# 7    2002  All Persons   Rate per 100,000 people1        Count    9.5
# 8    2002      Females                     Deaths        Count   89.0
# 9    2002      Females  Rate per 100,000 females1        Count    6.2
# 10   2002        Males                     Deaths        Count  173.0
# 11   2002        Males    Rate per 100,000 males1        Count   13.0
# 12   2003  All Persons                     Deaths        Count  286.0
# 13   2003  All Persons   Rate per 100,000 people1        Count   10.3
# 14   2003      Females                     Deaths        Count   93.0
# 15   2003      Females  Rate per 100,000 females1        Count    6.4
# 16   2003        Males                     Deaths        Count  193.0
# 17   2003        Males    Rate per 100,000 males1        Count   14.6
# 18   2004  All Persons                     Deaths        Count  319.0
# 19   2004  All Persons   Rate per 100,000 people1        Count   11.3
# 20   2004      Females                     Deaths        Count  115.0
# 21   2004      Females  Rate per 100,000 females1        Count    7.8
# 22   2004        Males                     Deaths        Count  204.0
# 23   2004        Males    Rate per 100,000 males1        Count   14.9
# 24   2005  All Persons                     Deaths        Count  321.0
# 25   2005  All Persons   Rate per 100,000 people1        Count   11.2
# 26   2005      Females                     Deaths        Count  114.0
# 27   2005      Females  Rate per 100,000 females1        Count    7.7
# 28   2005        Males                     Deaths        Count  207.0
# 29   2005        Males    Rate per 100,000 males1        Count   14.9
# ..    ...          ...                        ...          ...    ...
# 72   2013  All Persons                     Deaths        Count  386.0
# 73   2013  All Persons   Rate per 100,000 people1        Count   12.7
# 74   2013      Females                     Deaths        Count  133.0
# 75   2013      Females  Rate per 100,000 females1        Count    8.6
# 76   2013        Males                     Deaths        Count  253.0
# 77   2013        Males    Rate per 100,000 males1        Count   17.0
# 78   2014  All Persons                     Deaths        Count  351.0
# 79   2014  All Persons   Rate per 100,000 people1        Count   11.5
# 80   2014      Females                     Deaths        Count  121.0
# 81   2014      Females  Rate per 100,000 females1        Count    7.7
# 82   2014        Males                     Deaths        Count  230.0
# 83   2014        Males    Rate per 100,000 males1        Count   15.5
# 84   2015  All Persons                     Deaths        Count  361.0
# 85   2015  All Persons   Rate per 100,000 people1        Count   11.9
# 86   2015      Females                     Deaths        Count  132.0
# 87   2015      Females  Rate per 100,000 females1        Count    8.5
# 88   2015        Males                     Deaths        Count  229.0
# 89   2015        Males    Rate per 100,000 males1        Count   15.4
# 90   2016  All Persons                     Deaths        Count  388.0
# 91   2016  All Persons   Rate per 100,000 people1        Count   12.7
# 92   2016      Females                     Deaths        Count  130.0
# 93   2016      Females  Rate per 100,000 females1        Count    8.3
# 94   2016        Males                     Deaths        Count  258.0
# 95   2016        Males    Rate per 100,000 males1        Count   17.4
# 96   2017  All Persons                     Deaths        Count  419.0
# 97   2017  All Persons   Rate per 100,000 people1        Count   13.5
# 98   2017      Females                     Deaths        Count  148.0
# 99   2017      Females  Rate per 100,000 females1        Count    9.2
# 100  2017        Males                     Deaths        Count  271.0
# 101  2017        Males    Rate per 100,000 males1        Count   18.0
#
#      Lower 95% confidence limit  Upper 95% confidence limit    Unit
# 0                           8.9                        11.3  People
# 1                           8.9                        11.3  People
# 2                           5.5                         8.3  People
# 3                           5.5                         8.3  People
# 4                          11.6                        15.5  People
# 5                          11.6                        15.5  People
# 6                           8.3                        10.6  People
# 7                           8.3                        10.6  People
# 8                           5.0                         7.6  People
# 9                           5.0                         7.6  People
# 10                         11.1                        15.0  People
# 11                         11.1                        15.0  People
# 12                          9.1                        11.5  People
# 13                          9.1                        11.5  People
# 14                          5.2                         7.9  People
# 15                          5.2                         7.9  People
# 16                         12.5                        16.6  People
# 17                         12.5                        16.6  People
# 18                         10.1                        12.6  People
# 19                         10.1                        12.6  People
# 20                          6.4                         9.3  People
# 21                          6.4                         9.3  People
# 22                         12.9                        17.0  People
# 23                         12.9                        17.0  People
# 24                          9.9                        12.4  People
# 25                          9.9                        12.4  People
# 26                          6.3                         9.2  People
# 27                          6.3                         9.2  People
# 28                         12.9                        17.0  People
# 29                         12.9                        17.0  People
# ..                          ...                         ...     ...
# 72                         11.4                        14.0  People
# 73                         11.4                        14.0  People
# 74                          7.1                        10.1  People
# 75                          7.1                        10.1  People
# 76                         14.9                        19.1  People
# 77                         14.9                        19.1  People
# 78                         10.3                        12.7  People
# 79                         10.3                        12.7  People
# 80                          6.3                         9.1  People
# 81                          6.3                         9.1  People
# 82                         13.5                        17.5  People
# 83                         13.5                        17.5  People
# 84                         10.6                        13.1  People
# 85                         10.6                        13.1  People
# 86                          7.0                         9.9  People
# 87                          7.0                         9.9  People
# 88                         13.4                        17.4  People
# 89                         13.4                        17.4  People
# 90                         11.4                        14.0  People
# 91                         11.4                        14.0  People
# 92                          6.9                         9.8  People
# 93                          6.9                         9.8  People
# 94                         15.2                        19.5  People
# 95                         15.2                        19.5  People
# 96                         12.2                        14.8  People
# 97                         12.2                        14.8  People
# 98                          7.7                        10.7  People
# 99                          7.7                        10.7  People
# 100                        15.8                        20.1  People
# 101                        15.8                        20.1  People
#
# [102 rows x 8 columns]

# %%
Final_table.columns = ['Alcohol Specific Deaths' if x=='Alcohol Specific Deaths_x' else x for x in Final_table.columns]

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Lower 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Lower 95% confidence limit']), axis = 1)

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Upper 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Upper 95% confidence limit']), axis = 1)

# %%
Final_table['Alcohol Specific Deaths'] = Final_table['Alcohol Specific Deaths'].str.rstrip('1')

# %%
Final_table['Sex'] = Final_table['Sex'].map(
    lambda x: {
        'All persons' : 'T', 
        'Males' : 'M',
        'Females': 'F'         
        }.get(x, x))

# %%
Final_table['Age'] =  'All'

# %%
Final_table['Geography'] =  'W92000004'

# %%
Final_table
# Out:
#      Year          Sex   Alcohol Specific Deaths Measure Type  Value  \
# 0    2001  All Persons                    Deaths        Count  277.0
# 1    2001  All Persons   Rate per 100,000 people        Count   10.1
# 2    2001            F                    Deaths        Count   96.0
# 3    2001            F  Rate per 100,000 females        Count    6.8
# 4    2001            M                    Deaths        Count  181.0
# 5    2001            M    Rate per 100,000 males        Count   13.6
# 6    2002  All Persons                    Deaths        Count  262.0
# 7    2002  All Persons   Rate per 100,000 people        Count    9.5
# 8    2002            F                    Deaths        Count   89.0
# 9    2002            F  Rate per 100,000 females        Count    6.2
# 10   2002            M                    Deaths        Count  173.0
# 11   2002            M    Rate per 100,000 males        Count   13.0
# 12   2003  All Persons                    Deaths        Count  286.0
# 13   2003  All Persons   Rate per 100,000 people        Count   10.3
# 14   2003            F                    Deaths        Count   93.0
# 15   2003            F  Rate per 100,000 females        Count    6.4
# 16   2003            M                    Deaths        Count  193.0
# 17   2003            M    Rate per 100,000 males        Count   14.6
# 18   2004  All Persons                    Deaths        Count  319.0
# 19   2004  All Persons   Rate per 100,000 people        Count   11.3
# 20   2004            F                    Deaths        Count  115.0
# 21   2004            F  Rate per 100,000 females        Count    7.8
# 22   2004            M                    Deaths        Count  204.0
# 23   2004            M    Rate per 100,000 males        Count   14.9
# 24   2005  All Persons                    Deaths        Count  321.0
# 25   2005  All Persons   Rate per 100,000 people        Count   11.2
# 26   2005            F                    Deaths        Count  114.0
# 27   2005            F  Rate per 100,000 females        Count    7.7
# 28   2005            M                    Deaths        Count  207.0
# 29   2005            M    Rate per 100,000 males        Count   14.9
# ..    ...          ...                       ...          ...    ...
# 72   2013  All Persons                    Deaths        Count  386.0
# 73   2013  All Persons   Rate per 100,000 people        Count   12.7
# 74   2013            F                    Deaths        Count  133.0
# 75   2013            F  Rate per 100,000 females        Count    8.6
# 76   2013            M                    Deaths        Count  253.0
# 77   2013            M    Rate per 100,000 males        Count   17.0
# 78   2014  All Persons                    Deaths        Count  351.0
# 79   2014  All Persons   Rate per 100,000 people        Count   11.5
# 80   2014            F                    Deaths        Count  121.0
# 81   2014            F  Rate per 100,000 females        Count    7.7
# 82   2014            M                    Deaths        Count  230.0
# 83   2014            M    Rate per 100,000 males        Count   15.5
# 84   2015  All Persons                    Deaths        Count  361.0
# 85   2015  All Persons   Rate per 100,000 people        Count   11.9
# 86   2015            F                    Deaths        Count  132.0
# 87   2015            F  Rate per 100,000 females        Count    8.5
# 88   2015            M                    Deaths        Count  229.0
# 89   2015            M    Rate per 100,000 males        Count   15.4
# 90   2016  All Persons                    Deaths        Count  388.0
# 91   2016  All Persons   Rate per 100,000 people        Count   12.7
# 92   2016            F                    Deaths        Count  130.0
# 93   2016            F  Rate per 100,000 females        Count    8.3
# 94   2016            M                    Deaths        Count  258.0
# 95   2016            M    Rate per 100,000 males        Count   17.4
# 96   2017  All Persons                    Deaths        Count  419.0
# 97   2017  All Persons   Rate per 100,000 people        Count   13.5
# 98   2017            F                    Deaths        Count  148.0
# 99   2017            F  Rate per 100,000 females        Count    9.2
# 100  2017            M                    Deaths        Count  271.0
# 101  2017            M    Rate per 100,000 males        Count   18.0
#
#     Lower 95% confidence limit Upper 95% confidence limit    Unit  Age  \
# 0                                                          People  All
# 1                          8.9                       11.3  People  All
# 2                                                          People  All
# 3                          5.5                        8.3  People  All
# 4                                                          People  All
# 5                         11.6                       15.5  People  All
# 6                                                          People  All
# 7                          8.3                       10.6  People  All
# 8                                                          People  All
# 9                            5                        7.6  People  All
# 10                                                         People  All
# 11                        11.1                         15  People  All
# 12                                                         People  All
# 13                         9.1                       11.5  People  All
# 14                                                         People  All
# 15                         5.2                        7.9  People  All
# 16                                                         People  All
# 17                        12.5                       16.6  People  All
# 18                                                         People  All
# 19                        10.1                       12.6  People  All
# 20                                                         People  All
# 21                         6.4                        9.3  People  All
# 22                                                         People  All
# 23                        12.9                         17  People  All
# 24                                                         People  All
# 25                         9.9                       12.4  People  All
# 26                                                         People  All
# 27                         6.3                        9.2  People  All
# 28                                                         People  All
# 29                        12.9                         17  People  All
# ..                         ...                        ...     ...  ...
# 72                                                         People  All
# 73                        11.4                         14  People  All
# 74                                                         People  All
# 75                         7.1                       10.1  People  All
# 76                                                         People  All
# 77                        14.9                       19.1  People  All
# 78                                                         People  All
# 79                        10.3                       12.7  People  All
# 80                                                         People  All
# 81                         6.3                        9.1  People  All
# 82                                                         People  All
# 83                        13.5                       17.5  People  All
# 84                                                         People  All
# 85                        10.6                       13.1  People  All
# 86                                                         People  All
# 87                           7                        9.9  People  All
# 88                                                         People  All
# 89                        13.4                       17.4  People  All
# 90                                                         People  All
# 91                        11.4                         14  People  All
# 92                                                         People  All
# 93                         6.9                        9.8  People  All
# 94                                                         People  All
# 95                        15.2                       19.5  People  All
# 96                                                         People  All
# 97                        12.2                       14.8  People  All
# 98                                                         People  All
# 99                         7.7                       10.7  People  All
# 100                                                        People  All
# 101                       15.8                       20.1  People  All
#
#      Geography
# 0    W92000004
# 1    W92000004
# 2    W92000004
# 3    W92000004
# 4    W92000004
# 5    W92000004
# 6    W92000004
# 7    W92000004
# 8    W92000004
# 9    W92000004
# 10   W92000004
# 11   W92000004
# 12   W92000004
# 13   W92000004
# 14   W92000004
# 15   W92000004
# 16   W92000004
# 17   W92000004
# 18   W92000004
# 19   W92000004
# 20   W92000004
# 21   W92000004
# 22   W92000004
# 23   W92000004
# 24   W92000004
# 25   W92000004
# 26   W92000004
# 27   W92000004
# 28   W92000004
# 29   W92000004
# ..         ...
# 72   W92000004
# 73   W92000004
# 74   W92000004
# 75   W92000004
# 76   W92000004
# 77   W92000004
# 78   W92000004
# 79   W92000004
# 80   W92000004
# 81   W92000004
# 82   W92000004
# 83   W92000004
# 84   W92000004
# 85   W92000004
# 86   W92000004
# 87   W92000004
# 88   W92000004
# 89   W92000004
# 90   W92000004
# 91   W92000004
# 92   W92000004
# 93   W92000004
# 94   W92000004
# 95   W92000004
# 96   W92000004
# 97   W92000004
# 98   W92000004
# 99   W92000004
# 100  W92000004
# 101  W92000004
#
# [102 rows x 10 columns]

# %%
Final_table.count()
# Out:
# Year                          102
# Sex                           102
# Alcohol Specific Deaths       102
# Measure Type                  102
# Value                         102
# Lower 95% confidence limit    102
# Upper 95% confidence limit    102
# Unit                          102
# Age                           102
# Geography                     102
# dtype: int64
