# %% [markdown]
# Table 4: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in England, 2001 to 2016

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/healthandsocialcare/causesofdeath/datasets/alcoholspecificdeathsintheukmaindataset')
    sheet = scraper.distribution().as_databaker()
# Out:
# WARNING:Unexpected "next release" field: ('Unknown string format:', 'To be announced')

# %%
tab = next(tab for tab in sheet if tab.name=='Table 4')

# %%
observations = tab.excel_ref('C7').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<D13 6.9>, <E7 5.3>, <C15 1665.0>, <H12 3341.0>, <D11 6.2>, <J10 13.0>, <H14 3633.0>, <D16 6.6>, <H13 3365.0>, <F17 7.3>, <F7 5.9>, <J12 14.1>, <K18 14.1>, <F21 7.1>, <C9 1374.0>, <H7 2698.0>, <D10 6.4>, <H17 3666.0>, <K10 13.9>, <D22 6.8>, <J15 13.8>, <F8 6.0>, <I15 14.3>, <F10 6.7>, <C18 1699.0>, <C21 1796.0>, <C20 1803.0>, <K16 15.3>, <K15 14.8>, <K8 13.2>, <E13 6.6>, <C8 1331.0>, <K12 15.1>, <E10 6.0>, <H22 3687.0>, <H20 3583.0>, <F19 6.9>, <K9 14.1>, <H16 3562.0>, <J22 14.0>, <E18 6.3>, <E20 6.6>, <I22 14.5>, <J20 13.9>, <E22 6.5>, <C7 1305.0>, <H9 3050.0>, <C10 1508.0>, <I7 12.3>, <J14 15.0>, <F13 7.2>, <D8 5.7>, <I19 14.1>, <I10 13.4>, <K22 14.9>, <K20 14.8>, <C22 1820.0>, <E8 5.4>, <J13 14.0>, <E11 5.9>, <D12 6.7>, <J9 13.2>, <D15 6.7>, <C14 1712.0>, <I17 15.1>, <J11 13.8>, <C16 1661.0>, <H8 2784.0>, <K19 14.6>, <F22 7.1>, <H19 3485.0>, <D14 7.0>, <I13 14.5>, <F20 7.2>, <J16 14.3>, <D20 6.9>, <H15 3418.0>, <F11 6.5>, <D18 6.6>, <H18 3344.0>, <D21 6.8>, <I11 14.3>, <H10 3008.0>, <I16 14.8>, <D19 6.6>, <F9 6.1>, <E12 6.4>, <D17 7.0>, <I12 14.6>, <C13 1688.0>, <C19 1699.0>, <E14 6.6>, <I18 13.7>, <K14 16.0>, <E16 6.3>, <F16 6.9>, <K13 15.0>, <F18 6.9>, <J18 13.2>, <C12 1620.0>, <H21 3510.0>, <E21 6.5>, <E15 6.3>, <I21 13.9>, <J7 11.9>, <K11 14.8>, <J17 14.6>, <E17 6.6>, <I14 15.5>, <E19 6.3>, <J8 12.2>, <J19 13.6>, <K7 12.8>, <D9 5.8>, <J21 13.5>, <H11 3224.0>, <I8 12.7>, <K17 15.6>, <C17 1770.0>, <C11 1493.0>, <F14 7.3>, <E9 5.5>, <F12 7.0>, <I20 14.4>, <I9 13.7>, <D7 5.6>, <F15 7.0>, <K21 14.4>}

# %%
Sex = tab.excel_ref('C5').expand(RIGHT).is_not_whitespace()
Sex
# Out:
# {<H5 'Males'>, <C5 'Females'>}

# %%
deaths = tab.excel_ref('C6').expand(RIGHT).is_not_blank()
deaths
# Out:
# {<I6 'Rate per 100,000 persons1'>, <C6 'Deaths'>, <K6 'Upper 95% confidence limit'>, <E6 'Lower 95% confidence limit'>, <H6 'Deaths'>, <J6 'Lower 95% confidence limit'>, <D6 'Rate per 100,000 persons1'>, <F6 'Upper 95% confidence limit'>}

# %%
Year = tab.excel_ref('A7').expand(DOWN) - tab.excel_ref('A23').expand(DOWN)  
Year
# Out:
# {<A9 2003.0>, <A21 2015.0>, <A12 2006.0>, <A13 2007.0>, <A19 2013.0>, <A15 2009.0>, <A10 2004.0>, <A20 2014.0>, <A11 2005.0>, <A17 2011.0>, <A14 2008.0>, <A8 2002.0>, <A18 2012.0>, <A22 2016.0>, <A7 2001.0>, <A16 2010.0>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(Sex,'Sex',CLOSEST,LEFT),
            HDim(deaths, 'Alcohol Specific Deaths',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Sex</td><td class="xc3" style="background-color:LightGray">Alcohol Specific Deaths</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4</caption>
# <tr><td title="0 0">Back to contents</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td><td title="11 0"></td></tr>
# <tr><td style="font-weight:bold" title="0 1">Table 4: Alcohol-specific age-standardised death rates per 100,000 population, deaths registered in England, 2001 to 20161,2,3,4</td><td style="font-weight:bold" title="1 1"></td><td style="font-weight:bold" title="2 1"></td><td style="font-weight:bold" title="3 1"></td><td style="font-weight:bold" title="4 1"></td><td style="font-weight:bold" title="5 1"></td><td style="font-weight:bold" title="6 1"></td><td style="font-weight:bold" title="7 1"></td><td style="font-weight:bold" title="8 1"></td><td style="font-weight:bold" title="9 1"></td><td style="font-weight:bold" title="10 1"></td><td title="11 1"></td></tr>
# <tr><td style="font-weight:bold" title="0 2"></td><td style="font-weight:bold" title="1 2"></td><td style="font-weight:bold" title="2 2"></td><td style="font-weight:bold" title="3 2"></td><td style="font-weight:bold" title="4 2"></td><td style="font-weight:bold" title="5 2"></td><td style="font-weight:bold" title="6 2"></td><td style="font-weight:bold" title="7 2"></td><td style="font-weight:bold" title="8 2"></td><td style="font-weight:bold" title="9 2"></td><td style="font-weight:bold" title="10 2"></td><td title="11 2"></td></tr>
# <tr><td style="font-weight:bold" title="0 3"></td><td style="font-weight:bold" title="1 3"></td><td style="font-weight:bold" title="2 3"></td><td style="font-weight:bold" title="3 3"></td><td style="font-weight:bold" title="4 3"></td><td style="font-weight:bold" title="5 3"></td><td style="font-weight:bold" title="6 3"></td><td title="7 3"></td><td title="8 3"></td><td title="9 3"></td><td title="10 3"></td><td title="11 3"></td></tr>
# <tr><td style="font-weight:bold" title="0 4"></td><td style="font-weight:bold" title="1 4"></td><td style="background-color:MistyRose;font-weight:bold" title="2 4">Females</td><td style="font-weight:bold" title="3 4"></td><td style="font-weight:bold" title="4 4"></td><td style="font-weight:bold" title="5 4"></td><td style="font-weight:bold" title="6 4"></td><td style="background-color:MistyRose;font-weight:bold" title="7 4">Males</td><td style="font-weight:bold" title="8 4"></td><td style="font-weight:bold" title="9 4"></td><td style="font-weight:bold" title="10 4"></td><td title="11 4"></td></tr>
# <tr><td style="font-weight:bold" title="0 5">Year</td><td style="font-weight:bold" title="1 5"></td><td style="background-color:LightGray;font-weight:bold" title="2 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="3 5">Rate per 100,000 persons1</td><td style="background-color:LightGray;font-weight:bold" title="4 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="5 5">Upper 95% confidence limit</td><td title="6 5"></td><td style="background-color:LightGray;font-weight:bold" title="7 5">Deaths</td><td style="background-color:LightGray;font-weight:bold" title="8 5">Rate per 100,000 persons1</td><td style="background-color:LightGray;font-weight:bold" title="9 5">Lower 95% confidence limit</td><td style="background-color:LightGray;font-weight:bold" title="10 5">Upper 95% confidence limit</td><td title="11 5"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">2001.0</td><td title="1 6"></td><td style="background-color:Aqua" title="2 6">1305.0</td><td style="background-color:Aqua" title="3 6">5.6</td><td style="background-color:Aqua" title="4 6">5.3</td><td style="background-color:Aqua" title="5 6">5.9</td><td title="6 6"></td><td style="background-color:Aqua" title="7 6">2698.0</td><td style="background-color:Aqua" title="8 6">12.3</td><td style="background-color:Aqua" title="9 6">11.9</td><td style="background-color:Aqua" title="10 6">12.8</td><td title="11 6"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 7">2002.0</td><td title="1 7"></td><td style="background-color:Aqua" title="2 7">1331.0</td><td style="background-color:Aqua" title="3 7">5.7</td><td style="background-color:Aqua" title="4 7">5.4</td><td style="background-color:Aqua" title="5 7">6.0</td><td title="6 7"></td><td style="background-color:Aqua" title="7 7">2784.0</td><td style="background-color:Aqua" title="8 7">12.7</td><td style="background-color:Aqua" title="9 7">12.2</td><td style="background-color:Aqua" title="10 7">13.2</td><td title="11 7"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 8">2003.0</td><td title="1 8"></td><td style="background-color:Aqua" title="2 8">1374.0</td><td style="background-color:Aqua" title="3 8">5.8</td><td style="background-color:Aqua" title="4 8">5.5</td><td style="background-color:Aqua" title="5 8">6.1</td><td title="6 8"></td><td style="background-color:Aqua" title="7 8">3050.0</td><td style="background-color:Aqua" title="8 8">13.7</td><td style="background-color:Aqua" title="9 8">13.2</td><td style="background-color:Aqua" title="10 8">14.1</td><td title="11 8"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 9">2004.0</td><td title="1 9"></td><td style="background-color:Aqua" title="2 9">1508.0</td><td style="background-color:Aqua" title="3 9">6.4</td><td style="background-color:Aqua" title="4 9">6.0</td><td style="background-color:Aqua" title="5 9">6.7</td><td title="6 9"></td><td style="background-color:Aqua" title="7 9">3008.0</td><td style="background-color:Aqua" title="8 9">13.4</td><td style="background-color:Aqua" title="9 9">13.0</td><td style="background-color:Aqua" title="10 9">13.9</td><td title="11 9"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 10">2005.0</td><td title="1 10"></td><td style="background-color:Aqua" title="2 10">1493.0</td><td style="background-color:Aqua" title="3 10">6.2</td><td style="background-color:Aqua" title="4 10">5.9</td><td style="background-color:Aqua" title="5 10">6.5</td><td title="6 10"></td><td style="background-color:Aqua" title="7 10">3224.0</td><td style="background-color:Aqua" title="8 10">14.3</td><td style="background-color:Aqua" title="9 10">13.8</td><td style="background-color:Aqua" title="10 10">14.8</td><td title="11 10"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 11">2006.0</td><td title="1 11"></td><td style="background-color:Aqua" title="2 11">1620.0</td><td style="background-color:Aqua" title="3 11">6.7</td><td style="background-color:Aqua" title="4 11">6.4</td><td style="background-color:Aqua" title="5 11">7.0</td><td title="6 11"></td><td style="background-color:Aqua" title="7 11">3341.0</td><td style="background-color:Aqua" title="8 11">14.6</td><td style="background-color:Aqua" title="9 11">14.1</td><td style="background-color:Aqua" title="10 11">15.1</td><td title="11 11"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 12">2007.0</td><td title="1 12"></td><td style="background-color:Aqua" title="2 12">1688.0</td><td style="background-color:Aqua" title="3 12">6.9</td><td style="background-color:Aqua" title="4 12">6.6</td><td style="background-color:Aqua" title="5 12">7.2</td><td title="6 12"></td><td style="background-color:Aqua" title="7 12">3365.0<

# %%
new_table = c1.topandas()
new_table
# Out:
#         OBS    Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 0    1305.0  2001.0  Females                      Deaths        Count  People
# 1       5.6  2001.0  Females   Rate per 100,000 persons1        Count  People
# 2       5.3  2001.0  Females  Lower 95% confidence limit        Count  People
# 3       5.9  2001.0  Females  Upper 95% confidence limit        Count  People
# 4    2698.0  2001.0    Males                      Deaths        Count  People
# 5      12.3  2001.0    Males   Rate per 100,000 persons1        Count  People
# 6      11.9  2001.0    Males  Lower 95% confidence limit        Count  People
# 7      12.8  2001.0    Males  Upper 95% confidence limit        Count  People
# 8    1331.0  2002.0  Females                      Deaths        Count  People
# 9       5.7  2002.0  Females   Rate per 100,000 persons1        Count  People
# 10      5.4  2002.0  Females  Lower 95% confidence limit        Count  People
# 11      6.0  2002.0  Females  Upper 95% confidence limit        Count  People
# 12   2784.0  2002.0    Males                      Deaths        Count  People
# 13     12.7  2002.0    Males   Rate per 100,000 persons1        Count  People
# 14     12.2  2002.0    Males  Lower 95% confidence limit        Count  People
# 15     13.2  2002.0    Males  Upper 95% confidence limit        Count  People
# 16   1374.0  2003.0  Females                      Deaths        Count  People
# 17      5.8  2003.0  Females   Rate per 100,000 persons1        Count  People
# 18      5.5  2003.0  Females  Lower 95% confidence limit        Count  People
# 19      6.1  2003.0  Females  Upper 95% confidence limit        Count  People
# 20   3050.0  2003.0    Males                      Deaths        Count  People
# 21     13.7  2003.0    Males   Rate per 100,000 persons1        Count  People
# 22     13.2  2003.0    Males  Lower 95% confidence limit        Count  People
# 23     14.1  2003.0    Males  Upper 95% confidence limit        Count  People
# 24   1508.0  2004.0  Females                      Deaths        Count  People
# 25      6.4  2004.0  Females   Rate per 100,000 persons1        Count  People
# 26      6.0  2004.0  Females  Lower 95% confidence limit        Count  People
# 27      6.7  2004.0  Females  Upper 95% confidence limit        Count  People
# 28   3008.0  2004.0    Males                      Deaths        Count  People
# 29     13.4  2004.0    Males   Rate per 100,000 persons1        Count  People
# ..      ...     ...      ...                         ...          ...     ...
# 98      6.3  2013.0  Females  Lower 95% confidence limit        Count  People
# 99      6.9  2013.0  Females  Upper 95% confidence limit        Count  People
# 100  3485.0  2013.0    Males                      Deaths        Count  People
# 101    14.1  2013.0    Males   Rate per 100,000 persons1        Count  People
# 102    13.6  2013.0    Males  Lower 95% confidence limit        Count  People
# 103    14.6  2013.0    Males  Upper 95% confidence limit        Count  People
# 104  1803.0  2014.0  Females                      Deaths        Count  People
# 105     6.9  2014.0  Females   Rate per 100,000 persons1        Count  People
# 106     6.6  2014.0  Females  Lower 95% confidence limit        Count  People
# 107     7.2  2014.0  Females  Upper 95% confidence limit        Count  People
# 108  3583.0  2014.0    Males                      Deaths        Count  People
# 109    14.4  2014.0    Males   Rate per 100,000 persons1        Count  People
# 110    13.9  2014.0    Males  Lower 95% confidence limit        Count  People
# 111    14.8  2014.0    Males  Upper 95% confidence limit        Count  People
# 112  1796.0  2015.0  Females                      Deaths        Count  People
# 113     6.8  2015.0  Females   Rate per 100,000 persons1        Count  People
# 114     6.5  2015.0  Females  Lower 95% confidence limit        Count  People
# 115     7.1  2015.0  Females  Upper 95% confidence limit        Count  People
# 116  3510.0  2015.0    Males                      Deaths        Count  People
# 117    13.9  2015.0    Males   Rate per 100,000 persons1        Count  People
# 118    13.5  2015.0    Males  Lower 95% confidence limit        Count  People
# 119    14.4  2015.0    Males  Upper 95% confidence limit        Count  People
# 120  1820.0  2016.0  Females                      Deaths        Count  People
# 121     6.8  2016.0  Females   Rate per 100,000 persons1        Count  People
# 122     6.5  2016.0  Females  Lower 95% confidence limit        Count  People
# 123     7.1  2016.0  Females  Upper 95% confidence limit        Count  People
# 124  3687.0  2016.0    Males                      Deaths        Count  People
# 125    14.5  2016.0    Males   Rate per 100,000 persons1        Count  People
# 126    14.0  2016.0    Males  Lower 95% confidence limit        Count  People
# 127    14.9  2016.0    Males  Upper 95% confidence limit        Count  People
#
# [128 rows x 6 columns]

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
# new_table['Year'] = new_table['Year'].astype(str)

# %%
# new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value                      float64
# Year                         int64
# Sex                         object
# Alcohol Specific Deaths     object
# Measure Type                object
# Unit                        object
# dtype: object

# %%
new_table
# Out:
#       Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 0    1305.0  2001  Females                      Deaths        Count  People
# 1       5.6  2001  Females   Rate per 100,000 persons1        Count  People
# 2       5.3  2001  Females  Lower 95% confidence limit        Count  People
# 3       5.9  2001  Females  Upper 95% confidence limit        Count  People
# 4    2698.0  2001    Males                      Deaths        Count  People
# 5      12.3  2001    Males   Rate per 100,000 persons1        Count  People
# 6      11.9  2001    Males  Lower 95% confidence limit        Count  People
# 7      12.8  2001    Males  Upper 95% confidence limit        Count  People
# 8    1331.0  2002  Females                      Deaths        Count  People
# 9       5.7  2002  Females   Rate per 100,000 persons1        Count  People
# 10      5.4  2002  Females  Lower 95% confidence limit        Count  People
# 11      6.0  2002  Females  Upper 95% confidence limit        Count  People
# 12   2784.0  2002    Males                      Deaths        Count  People
# 13     12.7  2002    Males   Rate per 100,000 persons1        Count  People
# 14     12.2  2002    Males  Lower 95% confidence limit        Count  People
# 15     13.2  2002    Males  Upper 95% confidence limit        Count  People
# 16   1374.0  2003  Females                      Deaths        Count  People
# 17      5.8  2003  Females   Rate per 100,000 persons1        Count  People
# 18      5.5  2003  Females  Lower 95% confidence limit        Count  People
# 19      6.1  2003  Females  Upper 95% confidence limit        Count  People
# 20   3050.0  2003    Males                      Deaths        Count  People
# 21     13.7  2003    Males   Rate per 100,000 persons1        Count  People
# 22     13.2  2003    Males  Lower 95% confidence limit        Count  People
# 23     14.1  2003    Males  Upper 95% confidence limit        Count  People
# 24   1508.0  2004  Females                      Deaths        Count  People
# 25      6.4  2004  Females   Rate per 100,000 persons1        Count  People
# 26      6.0  2004  Females  Lower 95% confidence limit        Count  People
# 27      6.7  2004  Females  Upper 95% confidence limit        Count  People
# 28   3008.0  2004    Males                      Deaths        Count  People
# 29     13.4  2004    Males   Rate per 100,000 persons1        Count  People
# ..      ...   ...      ...                         ...          ...     ...
# 98      6.3  2013  Females  Lower 95% confidence limit        Count  People
# 99      6.9  2013  Females  Upper 95% confidence limit        Count  People
# 100  3485.0  2013    Males                      Deaths        Count  People
# 101    14.1  2013    Males   Rate per 100,000 persons1        Count  People
# 102    13.6  2013    Males  Lower 95% confidence limit        Count  People
# 103    14.6  2013    Males  Upper 95% confidence limit        Count  People
# 104  1803.0  2014  Females                      Deaths        Count  People
# 105     6.9  2014  Females   Rate per 100,000 persons1        Count  People
# 106     6.6  2014  Females  Lower 95% confidence limit        Count  People
# 107     7.2  2014  Females  Upper 95% confidence limit        Count  People
# 108  3583.0  2014    Males                      Deaths        Count  People
# 109    14.4  2014    Males   Rate per 100,000 persons1        Count  People
# 110    13.9  2014    Males  Lower 95% confidence limit        Count  People
# 111    14.8  2014    Males  Upper 95% confidence limit        Count  People
# 112  1796.0  2015  Females                      Deaths        Count  People
# 113     6.8  2015  Females   Rate per 100,000 persons1        Count  People
# 114     6.5  2015  Females  Lower 95% confidence limit        Count  People
# 115     7.1  2015  Females  Upper 95% confidence limit        Count  People
# 116  3510.0  2015    Males                      Deaths        Count  People
# 117    13.9  2015    Males   Rate per 100,000 persons1        Count  People
# 118    13.5  2015    Males  Lower 95% confidence limit        Count  People
# 119    14.4  2015    Males  Upper 95% confidence limit        Count  People
# 120  1820.0  2016  Females                      Deaths        Count  People
# 121     6.8  2016  Females   Rate per 100,000 persons1        Count  People
# 122     6.5  2016  Females  Lower 95% confidence limit        Count  People
# 123     7.1  2016  Females  Upper 95% confidence limit        Count  People
# 124  3687.0  2016    Males                      Deaths        Count  People
# 125    14.5  2016    Males   Rate per 100,000 persons1        Count  People
# 126    14.0  2016    Males  Lower 95% confidence limit        Count  People
# 127    14.9  2016    Males  Upper 95% confidence limit        Count  People
#
# [128 rows x 6 columns]

# %%
nt1 = new_table[new_table['Alcohol Specific Deaths'] == 'Lower 95% confidence limit']

# %%
nt1
# Out:
#      Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 2      5.3  2001  Females  Lower 95% confidence limit        Count  People
# 6     11.9  2001    Males  Lower 95% confidence limit        Count  People
# 10     5.4  2002  Females  Lower 95% confidence limit        Count  People
# 14    12.2  2002    Males  Lower 95% confidence limit        Count  People
# 18     5.5  2003  Females  Lower 95% confidence limit        Count  People
# 22    13.2  2003    Males  Lower 95% confidence limit        Count  People
# 26     6.0  2004  Females  Lower 95% confidence limit        Count  People
# 30    13.0  2004    Males  Lower 95% confidence limit        Count  People
# 34     5.9  2005  Females  Lower 95% confidence limit        Count  People
# 38    13.8  2005    Males  Lower 95% confidence limit        Count  People
# 42     6.4  2006  Females  Lower 95% confidence limit        Count  People
# 46    14.1  2006    Males  Lower 95% confidence limit        Count  People
# 50     6.6  2007  Females  Lower 95% confidence limit        Count  People
# 54    14.0  2007    Males  Lower 95% confidence limit        Count  People
# 58     6.6  2008  Females  Lower 95% confidence limit        Count  People
# 62    15.0  2008    Males  Lower 95% confidence limit        Count  People
# 66     6.3  2009  Females  Lower 95% confidence limit        Count  People
# 70    13.8  2009    Males  Lower 95% confidence limit        Count  People
# 74     6.3  2010  Females  Lower 95% confidence limit        Count  People
# 78    14.3  2010    Males  Lower 95% confidence limit        Count  People
# 82     6.6  2011  Females  Lower 95% confidence limit        Count  People
# 86    14.6  2011    Males  Lower 95% confidence limit        Count  People
# 90     6.3  2012  Females  Lower 95% confidence limit        Count  People
# 94    13.2  2012    Males  Lower 95% confidence limit        Count  People
# 98     6.3  2013  Females  Lower 95% confidence limit        Count  People
# 102   13.6  2013    Males  Lower 95% confidence limit        Count  People
# 106    6.6  2014  Females  Lower 95% confidence limit        Count  People
# 110   13.9  2014    Males  Lower 95% confidence limit        Count  People
# 114    6.5  2015  Females  Lower 95% confidence limit        Count  People
# 118   13.5  2015    Males  Lower 95% confidence limit        Count  People
# 122    6.5  2016  Females  Lower 95% confidence limit        Count  People
# 126   14.0  2016    Males  Lower 95% confidence limit        Count  People

# %%
nt1.columns = ['Lower 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
nt2 = new_table[new_table['Alcohol Specific Deaths'] == 'Upper 95% confidence limit']

# %%
nt2
# Out:
#      Value  Year      Sex     Alcohol Specific Deaths Measure Type    Unit
# 3      5.9  2001  Females  Upper 95% confidence limit        Count  People
# 7     12.8  2001    Males  Upper 95% confidence limit        Count  People
# 11     6.0  2002  Females  Upper 95% confidence limit        Count  People
# 15    13.2  2002    Males  Upper 95% confidence limit        Count  People
# 19     6.1  2003  Females  Upper 95% confidence limit        Count  People
# 23    14.1  2003    Males  Upper 95% confidence limit        Count  People
# 27     6.7  2004  Females  Upper 95% confidence limit        Count  People
# 31    13.9  2004    Males  Upper 95% confidence limit        Count  People
# 35     6.5  2005  Females  Upper 95% confidence limit        Count  People
# 39    14.8  2005    Males  Upper 95% confidence limit        Count  People
# 43     7.0  2006  Females  Upper 95% confidence limit        Count  People
# 47    15.1  2006    Males  Upper 95% confidence limit        Count  People
# 51     7.2  2007  Females  Upper 95% confidence limit        Count  People
# 55    15.0  2007    Males  Upper 95% confidence limit        Count  People
# 59     7.3  2008  Females  Upper 95% confidence limit        Count  People
# 63    16.0  2008    Males  Upper 95% confidence limit        Count  People
# 67     7.0  2009  Females  Upper 95% confidence limit        Count  People
# 71    14.8  2009    Males  Upper 95% confidence limit        Count  People
# 75     6.9  2010  Females  Upper 95% confidence limit        Count  People
# 79    15.3  2010    Males  Upper 95% confidence limit        Count  People
# 83     7.3  2011  Females  Upper 95% confidence limit        Count  People
# 87    15.6  2011    Males  Upper 95% confidence limit        Count  People
# 91     6.9  2012  Females  Upper 95% confidence limit        Count  People
# 95    14.1  2012    Males  Upper 95% confidence limit        Count  People
# 99     6.9  2013  Females  Upper 95% confidence limit        Count  People
# 103   14.6  2013    Males  Upper 95% confidence limit        Count  People
# 107    7.2  2014  Females  Upper 95% confidence limit        Count  People
# 111   14.8  2014    Males  Upper 95% confidence limit        Count  People
# 115    7.1  2015  Females  Upper 95% confidence limit        Count  People
# 119   14.4  2015    Males  Upper 95% confidence limit        Count  People
# 123    7.1  2016  Females  Upper 95% confidence limit        Count  People
# 127   14.9  2016    Males  Upper 95% confidence limit        Count  People

# %%
nt2.columns = ['Upper 95% confidence limit' if x=='Value' else x for x in new_table.columns]

# %%
new_table.count()
# Out:
# Value                      128
# Year                       128
# Sex                        128
# Alcohol Specific Deaths    128
# Measure Type               128
# Unit                       128
# dtype: int64

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Upper 95% confidence limit']

# %%
new_table = new_table[new_table['Alcohol Specific Deaths'] != 'Lower 95% confidence limit']

# %%
Final_table = pd.merge(new_table, nt1, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(2)
# Out:
#     Value  Year      Sex  Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0  1305.0  2001  Females                     Deaths          Count  People
# 1     5.6  2001  Females  Rate per 100,000 persons1          Count  People
#
#    Lower 95% confidence limit   Alcohol Specific Deaths_y Measure Type_y  \
# 0                         5.3  Lower 95% confidence limit          Count
# 1                         5.3  Lower 95% confidence limit          Count
#
#    Unit_y
# 0  People
# 1  People

# %%
Final_table = Final_table[['Value','Year','Sex','Alcohol Specific Deaths_x','Measure Type_x','Unit_x',
                           'Lower 95% confidence limit']]

# %%
Final_table = pd.merge(Final_table, nt2, how = 'inner', on = ['Year','Sex'])

# %%
Final_table.head(1)
# Out:
#     Value  Year      Sex Alcohol Specific Deaths_x Measure Type_x  Unit_x  \
# 0  1305.0  2001  Females                    Deaths          Count  People
#
#    Lower 95% confidence limit  Upper 95% confidence limit  \
# 0                         5.3                         5.9
#
#       Alcohol Specific Deaths Measure Type    Unit
# 0  Upper 95% confidence limit        Count  People

# %%
Final_table = Final_table[['Year','Sex','Alcohol Specific Deaths_x','Measure Type','Value','Lower 95% confidence limit', 'Upper 95% confidence limit','Unit']]

# %%
Final_table
# Out:
#     Year      Sex  Alcohol Specific Deaths_x Measure Type   Value  \
# 0   2001  Females                     Deaths        Count  1305.0
# 1   2001  Females  Rate per 100,000 persons1        Count     5.6
# 2   2001    Males                     Deaths        Count  2698.0
# 3   2001    Males  Rate per 100,000 persons1        Count    12.3
# 4   2002  Females                     Deaths        Count  1331.0
# 5   2002  Females  Rate per 100,000 persons1        Count     5.7
# 6   2002    Males                     Deaths        Count  2784.0
# 7   2002    Males  Rate per 100,000 persons1        Count    12.7
# 8   2003  Females                     Deaths        Count  1374.0
# 9   2003  Females  Rate per 100,000 persons1        Count     5.8
# 10  2003    Males                     Deaths        Count  3050.0
# 11  2003    Males  Rate per 100,000 persons1        Count    13.7
# 12  2004  Females                     Deaths        Count  1508.0
# 13  2004  Females  Rate per 100,000 persons1        Count     6.4
# 14  2004    Males                     Deaths        Count  3008.0
# 15  2004    Males  Rate per 100,000 persons1        Count    13.4
# 16  2005  Females                     Deaths        Count  1493.0
# 17  2005  Females  Rate per 100,000 persons1        Count     6.2
# 18  2005    Males                     Deaths        Count  3224.0
# 19  2005    Males  Rate per 100,000 persons1        Count    14.3
# 20  2006  Females                     Deaths        Count  1620.0
# 21  2006  Females  Rate per 100,000 persons1        Count     6.7
# 22  2006    Males                     Deaths        Count  3341.0
# 23  2006    Males  Rate per 100,000 persons1        Count    14.6
# 24  2007  Females                     Deaths        Count  1688.0
# 25  2007  Females  Rate per 100,000 persons1        Count     6.9
# 26  2007    Males                     Deaths        Count  3365.0
# 27  2007    Males  Rate per 100,000 persons1        Count    14.5
# 28  2008  Females                     Deaths        Count  1712.0
# 29  2008  Females  Rate per 100,000 persons1        Count     7.0
# ..   ...      ...                        ...          ...     ...
# 34  2009    Males                     Deaths        Count  3418.0
# 35  2009    Males  Rate per 100,000 persons1        Count    14.3
# 36  2010  Females                     Deaths        Count  1661.0
# 37  2010  Females  Rate per 100,000 persons1        Count     6.6
# 38  2010    Males                     Deaths        Count  3562.0
# 39  2010    Males  Rate per 100,000 persons1        Count    14.8
# 40  2011  Females                     Deaths        Count  1770.0
# 41  2011  Females  Rate per 100,000 persons1        Count     7.0
# 42  2011    Males                     Deaths        Count  3666.0
# 43  2011    Males  Rate per 100,000 persons1        Count    15.1
# 44  2012  Females                     Deaths        Count  1699.0
# 45  2012  Females  Rate per 100,000 persons1        Count     6.6
# 46  2012    Males                     Deaths        Count  3344.0
# 47  2012    Males  Rate per 100,000 persons1        Count    13.7
# 48  2013  Females                     Deaths        Count  1699.0
# 49  2013  Females  Rate per 100,000 persons1        Count     6.6
# 50  2013    Males                     Deaths        Count  3485.0
# 51  2013    Males  Rate per 100,000 persons1        Count    14.1
# 52  2014  Females                     Deaths        Count  1803.0
# 53  2014  Females  Rate per 100,000 persons1        Count     6.9
# 54  2014    Males                     Deaths        Count  3583.0
# 55  2014    Males  Rate per 100,000 persons1        Count    14.4
# 56  2015  Females                     Deaths        Count  1796.0
# 57  2015  Females  Rate per 100,000 persons1        Count     6.8
# 58  2015    Males                     Deaths        Count  3510.0
# 59  2015    Males  Rate per 100,000 persons1        Count    13.9
# 60  2016  Females                     Deaths        Count  1820.0
# 61  2016  Females  Rate per 100,000 persons1        Count     6.8
# 62  2016    Males                     Deaths        Count  3687.0
# 63  2016    Males  Rate per 100,000 persons1        Count    14.5
#
#     Lower 95% confidence limit  Upper 95% confidence limit    Unit
# 0                          5.3                         5.9  People
# 1                          5.3                         5.9  People
# 2                         11.9                        12.8  People
# 3                         11.9                        12.8  People
# 4                          5.4                         6.0  People
# 5                          5.4                         6.0  People
# 6                         12.2                        13.2  People
# 7                         12.2                        13.2  People
# 8                          5.5                         6.1  People
# 9                          5.5                         6.1  People
# 10                        13.2                        14.1  People
# 11                        13.2                        14.1  People
# 12                         6.0                         6.7  People
# 13                         6.0                         6.7  People
# 14                        13.0                        13.9  People
# 15                        13.0                        13.9  People
# 16                         5.9                         6.5  People
# 17                         5.9                         6.5  People
# 18                        13.8                        14.8  People
# 19                        13.8                        14.8  People
# 20                         6.4                         7.0  People
# 21                         6.4                         7.0  People
# 22                        14.1                        15.1  People
# 23                        14.1                        15.1  People
# 24                         6.6                         7.2  People
# 25                         6.6                         7.2  People
# 26                        14.0                        15.0  People
# 27                        14.0                        15.0  People
# 28                         6.6                         7.3  People
# 29                         6.6                         7.3  People
# ..                         ...                         ...     ...
# 34                        13.8                        14.8  People
# 35                        13.8                        14.8  People
# 36                         6.3                         6.9  People
# 37                         6.3                         6.9  People
# 38                        14.3                        15.3  People
# 39                        14.3                        15.3  People
# 40                         6.6                         7.3  People
# 41                         6.6                         7.3  People
# 42                        14.6                        15.6  People
# 43                        14.6                        15.6  People
# 44                         6.3                         6.9  People
# 45                         6.3                         6.9  People
# 46                        13.2                        14.1  People
# 47                        13.2                        14.1  People
# 48                         6.3                         6.9  People
# 49                         6.3                         6.9  People
# 50                        13.6                        14.6  People
# 51                        13.6                        14.6  People
# 52                         6.6                         7.2  People
# 53                         6.6                         7.2  People
# 54                        13.9                        14.8  People
# 55                        13.9                        14.8  People
# 56                         6.5                         7.1  People
# 57                         6.5                         7.1  People
# 58                        13.5                        14.4  People
# 59                        13.5                        14.4  People
# 60                         6.5                         7.1  People
# 61                         6.5                         7.1  People
# 62                        14.0                        14.9  People
# 63                        14.0                        14.9  People
#
# [64 rows x 8 columns]

# %%
Final_table.columns = ['Alcohol Specific Deaths' if x=='Alcohol Specific Deaths_x' else x for x in Final_table.columns]

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Lower 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Lower 95% confidence limit']), axis = 1)

# %%
def user_perc(x,y):
    
    if str(x) == 'Deaths':
        return ''
    else:
        return y
    
Final_table['Upper 95% confidence limit'] = Final_table.apply(lambda row: user_perc(row['Alcohol Specific Deaths'],row['Upper 95% confidence limit']), axis = 1)

# %%
Final_table['Alcohol Specific Deaths'] = Final_table['Alcohol Specific Deaths'].str.rstrip('1')

# %%
Final_table['Sex'] = Final_table['Sex'].map(
    lambda x: {
        'All persons' : 'T', 
        'Males' : 'M',
        'Females': 'F'         
        }.get(x, x))

# %%
Final_table['Age'] =  'All'

# %%
Final_table['Geography'] =  'E92000001'
